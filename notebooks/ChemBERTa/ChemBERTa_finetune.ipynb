# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !nvidia-smi
# Out:
# Sun May  7 10:14:23 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.105.01   Driver Version: 515.105.01   CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:13:00.0  On |                  N/A |
# |  0%   54C    P3    34W / 220W |    988MiB /  8192MiB |      9%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2684      G   /usr/lib/xorg/Xorg                268MiB |
# |    0   N/A  N/A      3224      G   /usr/bin/gnome-shell               68MiB |
# |    0   N/A  N/A      3252      G   ...libexec/mutter-x11-frames       75MiB |
# |    0   N/A  N/A    429500      G   ...740065187074975866,131072      108MiB |
# |    0   N/A  N/A    441827      G   ...1/usr/lib/firefox/firefox      262MiB |
# |    0   N/A  N/A    447284      G   ...RendererForSitePerProcess      200MiB |
# +-----------------------------------------------------------------------------+

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: ilkersigirci. Use `wandb login --relogin` to force relogin

# %%
# !pip install deepchem simpletransformers transformers torch jupyter
# !pip list | egrep "deepchem|simpletransformers|transformers|torch"
# Out:
# deepchem                   2.7.1
# simpletransformers         0.63.9
# torch                      2.0.0
# transformers               4.27.4

# %% [markdown]
# ## Imports

# %%
# NOTE: Tutorial version was 2.5.0

import deepchem
import logging

# from rdkit import Chem
# Test if NVIDIA apex training tool works. TODO: Why is this needed?
# from apex import amp

from thesis_work.chemberta.molnet_dataloader import (
    load_molnet_dataset,
    write_molnet_dataset_for_chemprop,
)

deepchem.__version__
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/home/ilker/Documents/MyRepos/thesis-work/.venv/lib/python3.10/site-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'pytorch_lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# '2.7.1'

# %%
logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# %% [markdown]
# # What is Transfer Learning, and how does ChemBERTa utilize it?
#
# Transfer learning is a research problem in machine learning that focuses on **storing knowledge gained while solving one problem and applying it to a different but related problem**.
#
# By pre-training directly on SMILES strings, and teaching ChemBERTa to recognize masked tokens in each string, the model learns a strong molecular representation. We then can take this model, trained on a structural chemistry task, and apply it to a suite of classification tasks in the MoleculeNet suite, from Tox21 to BBBP!

# %% [markdown]
# # Fine-tuning ChemBERTa on a Small Mollecular Dataset
#
# Our fine-tuning dataset, ClinTox, consists of qualitative data of drugs approved by the FDA and those that have failed clinical trials for toxicity reasons.
#
# The ClinTox dataset consists of 1478 binary labels for toxicity, using the SMILES representations for identifying molecules. The computational models produced from the dataset could become decision-making tools for government agencies in determining which drugs are of the greatest potential concern to human health. Additionally, these models can act as drug screening tools in the drug discovery pipelines for toxicity.

# %% [markdown]
# #But why use custom Smiles-Tokenizer's over BPE?
#
# In this tutorial, we will be comparing the BPE tokenization algorithm with a **custom SmilesTokenizer** based on a regex pattern, which we have released as part of DeepChem. To compare tokenizers, we pretrained an identical model tokenized using this novel tokenizer, on the PubChem-1M set. The pretrained model was evaluated on the BBBP and Tox21 in the paper. We found that the SmilesTokenizer narrowly outperformed the BPE algorithm by ∆PRC-AUC = $+0.021$.
#
# Though this result suggests that a more semantically relevant tokenization may provide performance benefits, further benchmarking on additional datasets is needed to validate this finding. **In this tutorial, we aim to do so, by testing this alternate model on the ClinTox dataset.**
#
# Let's fetch the Smiles Tokenizer's character per line vocabulary file, which can bve loaded from the DeepChem S3 data bucket:

# %%
# TODO: Needed for tokenizer training I think?

# !wget https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/vocab.txt

# %% [markdown]
# ## Data

# %%
import pandas as pd
import numpy as np

# protein_type = "clintox"
protein_type = "kinase"
# protein_type = "gpcr"
# protein_type = "protease"

# %%
if protein_type == "clintox":
    tasks, (train_df, valid_df, test_df), transformers = load_molnet_dataset(
        "clintox", tasks_wanted=None
    )

else:
    data_path = f"../../thesis_work/data/{protein_type}_smiles.csv"

    df = pd.read_csv(data_path)
    df.columns = ["text", "labels"]

    df = df.sample(frac=1, random_state=42)

    train_df, valid_df, test_df = np.split(
        # df.sample(frac=1), [int(0.6 * len(df)), int(0.8 * len(df))]
        df.sample(frac=1),
        [int(0.8 * len(df)), int(0.9 * len(df))],
    )

# %%
# check if our train and evaluation dataframes are setup properly. There should only be two columns for the SMILES string and its corresponding label.
print("Train Dataset: {}".format(train_df.shape))
print("Eval Dataset: {}".format(valid_df.shape))
print("Test Dataset: {}".format(test_df.shape))
# Out:
# Train Dataset: (53047, 2)
# Eval Dataset: (6631, 2)
# Test Dataset: (6631, 2)

# %%
train_df
# valid_df
# test_df
# Out:
#                                                     text  labels
# 39020  C=CC(=O)Nc1cccc(-c2nc(Nc3ccc(N4CCOCC4)c(F)c3)n...       0
# 64077  O=C(Nc1cccc(C(F)(F)F)c1)Nc1cn(CCNc2ncnc3ccsc23...       0
# 10698  CN(CC1(C#N)CCCCC1)C1CCN(C(=O)c2ccc(-n3cc(NC(=O...       1
# 49210  CN1C(=O)c2c(c3c4ccccc4n(C4OC(CO)C(O)C(O)C4O)c3...       0
# 15819            Cc1cccc(NC(=O)c2cc(Br)ccc2OCc2ccccc2)c1       1
# ...                                                  ...     ...
# 21861         FC(F)(F)C1(Nc2cc(-c3ccncc3)nc3cnccc23)CCC1       1
# 66188  C=CC(=O)Nc1cccc(CNc2nc(Nc3cc(F)c(N4CCOCC4)c(F)...       0
# 30227  CC(C)n1cc(C(=O)c2cncc(NCCc3cccnc3)n2)c2c(N)ncnc21       1
# 53790  COc1cc2c(cc1OC)-c1n[nH]c(-c3ccc(-c4cn(C)cn4)cc...       0
# 24692  CC(C)(O)C#Cc1cc2c(cc1F)OCCn1c-2nc(C(N)=O)c1C(=...       1
#
# [53047 rows x 2 columns]

# %% [markdown]
# ## Model

# %% [markdown]
# - Now, using `simple-transformer`, let's load the pre-trained model from HuggingFace's useful model-hub. We'll set the number of epochs to 10 in the arguments, but you can train for longer, and pass early-stopping as an argument to prevent overfitting.
# - Also make sure that `auto_weights` is set to True to do automatic weight balancing, as we are dealing with imbalanced toxicity datasets.
#   - FIXME: Not working with ClassificationArgs. If provivided as dict, if doesn't complain but is it actually used?

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import os

# NOTE: Necessary for training outside of Colab
os.environ["TOKENIZERS_PARALLELISM"] = "false"


model_args = ClassificationArgs(
    evaluate_each_epoch=True,
    evaluate_during_training_verbose=True,
    no_save=True,
    num_train_epochs=1,
    # overwrite_output_dir=True,
    # auto_weights=True, # NOTE: Not working
    # NOTE: Necessary for training outside of Colab
    use_multiprocessing=False,
    # dataloader_num_workers=0,
    # process_count=1,
    use_multiprocessing_for_evaluation=False,
)

# Early stopping
# model_args.use_early_stopping = True
# model_args.early_stopping_delta = 0.01
# model_args.early_stopping_metric = "mcc"
# model_args.early_stopping_metric_minimize = False
# model_args.early_stopping_patience = 5
# model_args.evaluate_during_training_steps = 1000

# model_type = "seyonec/PubChem10M_SMILES_BPE_396_250"  # BPE tokenizer
# model_type = "seyonec/SMILES_tokenized_PubChem_shard00_160k"  # Custom SMILES tokenizer

# model_type = "DeepChem/ChemBERTa-10M-MTR"
model_type = "DeepChem/ChemBERTa-77M-MLM"

# output_dir = "BPE_PubChem_10M_ClinTox_run"
# output_dir = "SmilesTokenizer_PubChem_10M_ClinTox_run"
# output_dir = f"{protein_type.upper()}_77M_MLM_Scaffold"

output_dir = f"{protein_type.upper()}_77M_MLM_Shuffle_80_10_10_epoch1"

# if not os.path.exists(f"results/{output_dir}"):
#     os.makedirs(output_dir)


# You can set class weights by using the optional weight argument
model = ClassificationModel(
    "roberta",
    model_type,
    args=model_args,
    # use_cuda=False,
)
# Out:
# Some weights of the model checkpoint at DeepChem/ChemBERTa-77M-MLM were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at DeepChem/ChemBERTa-77M-MLM and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(model.tokenizer)
# Out:
# RobertaTokenizerFast(name_or_path='DeepChem/ChemBERTa-77M-MLM', vocab_size=591, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': AddedToken("[MASK]", rstrip=False, lstrip=True, single_word=False, normalized=False)})

# %% [markdown]
# Train the model on the train scaffold set of ClinTox, and monitor our runs using W&B. We will evaluate the performance of our model each epoch using the validation set.

# %%
# Create directory to store model weights (change path accordingly to where you want!)
# !mkdir BPE_PubChem_10M_ClinTox_run

# Train the model
model.train_model(
    train_df,
    eval_df=valid_df,
    output_dir=f"results/{output_dir}",
    args={"wandb_project": output_dir},
)

# %% [markdown]
# We will be using the accuracy and PRC-AUC metrics (average precision score).
#
# - Clintox_77M_MLM_Scaffold:
#
#   - 'auroc': 0.6598721023181455, 'auprc': 0.9686162534366902, 'acc': 0.9391891891891891, 'eval_loss': 0.21732922604209498
#   - 'auroc': 0.6598721023181455, 'auprc': 0.9686162534366902, 'acc': 0.9391891891891891, 'eval_loss': 0.21732922604209498
#
# - Kinase_BPE_60_20_20:
#
#   - 'auprc': 0.5819903832629333, 'acc': 0.5187000452420449, 'eval_loss': 0.6947489678140716
#   - 'auprc': 0.5819903832629333, 'acc': 0.5549285423253196, 'eval_loss': 0.6947489678140716
#
# - Kinase_77M_MLM_Random:
#
#   - 'auroc': 0.7816713295079376, 'auprc': 0.7923752900766724, 'acc': 0.696576685266174, 'eval_loss': 0.5885900806172766
#   - 'auroc': 0.7816713295079376, 'auprc': 0.7923752900766724, 'acc': 0.6778493619534837, 'eval_loss': 0.5885900806172766
#
# - Kinase_77M_MLM_Random_epoch_1:
#
#   - None
#   - 'auroc': 0.7543682288335132, 'auprc': 0.7674025333716489, 'acc': 0.6585454274106363, 'eval_loss': 0.588208513610757
#
# - Kinase_77M_MLM_Scaffold_epoch_10:
#
#   - 'auroc': 0.8009122719662067, 'auprc': 0.8054774057518067, 'acc': 0.7210073895340069, 'eval_loss': 0.5609703987872787
#   - 'auroc': 0.8009122719662067, 'auprc': 0.8054774057518067, 'acc': 0.6842033467149147, 'eval_loss': 0.5609703987872787
#
# - GPRC_BPE_60_20_20:
#
#   - 'auroc': 0.5052311430060601, 'auprc': 0.5437956080844786, 'acc': 0.5227907660638141, 'eval_loss': 0.6958835787944132
#   - 'auroc': 0.5052311430060601, 'auprc': 0.5437956080844786, 'acc': 0.5486169810712278, 'eval_loss': 0.6958835787944132
#
# - PROTEASE_BPE_60_20_20:
#
#   - 'auroc': 0.5058419844941522, 'auprc': 0.453862209356516, 'acc': 0.4530363223609535, 'eval_loss': 0.721208622182268
#   - 'auroc': 0.5058419844941522, 'auprc': 0.453862209356516, 'acc': 0.44255565858638773, 'eval_loss': 0.721208622182268
#
# - PROTEASE_77M_MLM_Scaffold_epoch_10:
#   - 'auroc': 0.7980674578306961, 'auprc': 0.7416403521458773, 'acc': 0.7346765039727582, 'eval_loss': 0.5834547029871519
#   - 'auroc': 0.7980674578306961, 'auprc': 0.7416403521458773, 'acc': 0.6234580182996616, 'eval_loss': 0.5834547029871519

# %%
# import torch
# import gc

# torch.cuda.empty_cache()
# gc.collect()

# %%
# import wandb
# run = wandb.init(project=output_dir)

# %%
# FIXME: Takes to much time, 17 min for 6k samples

import sklearn

## accuracy
# result, model_outputs, wrong_predictions = model.eval_model(
#     test_df, acc=sklearn.metrics.accuracy_score
# )

## ROC-PRC
result, model_outputs, wrong_predictions = model.eval_model(
    test_df, acc=sklearn.metrics.average_precision_score
)

# %%
result
# Out:
# {'mcc': 0.36808729171911037,
#  'tp': 2537,
#  'tn': 2012,
#  'fp': 1049,
#  'fn': 1033,
#  'auroc': 0.7543682288335132,
#  'auprc': 0.7674025333716489,
#  'acc': 0.6585454274106363,
#  'eval_loss': 0.588208513610757}

# %%
model_outputs
# Out:
# array([[-0.79931641,  0.85546875],
#        [-0.65283203,  0.68603516],
#        [ 0.01628113, -0.01928711],
#        ...,
#        [-0.05737305,  0.08734131],
#        [-0.0067749 ,  0.06628418],
#        [ 0.01933289,  0.02659607]])

# %%
wrong_predictions
# Out:
# [{'guid': 0, 'text_a': 'COc1cc(C(=O)NC2CC2)ccc1-c1cnc2c(NCCCN)nc(C#CCO)cn12', 'text_b': None, 'label': 0},
#  {'guid': 4, 'text_a': 'CCNC1=N/C(=C\\c2c[nH]c3ncccc23)C(=O)N1', 'text_b': None, 'label': 1},
#  {'guid': 5, 'text_a': 'CC1=CC(=O)N(Nc2nc(-c3cccs3)nc3sc(-c4ccc(OCCNCC(C)C)cc4)c(C)c23)C1=O.Cl', 'text_b': None, 'label': 1},
#  {'guid': 8, 'text_a': 'CC(Oc1cc(-n2cnc3cc(OCCCN(C)C)ccc32)ccc1C(N)=O)c1ccccc1C(F)(F)F', 'text_b': None, 'label': 0},
#  {'guid': 11, 'text_a': 'O=Cc1cn2c3c1ccc1c4ccccc4n(c13)CCCC2', 'text_b': None, 'label': 1},
#  {'guid': 15, 'text_a': 'CCC1C(=O)N(C)c2cnc(Nc3cc(F)c(C(=O)NC4CCCC4)cc3OCCO)nc2N1C1CCCC1', 'text_b': None, 'label': 0},
#  {'guid': 17, 'text_a': 'CN(c1ccc(F)cc1)c1cc2cnnc(-c3ccc(F)cc3F)c2n(C)c1=O', 'text_b': None, 'label': 0},
#  {'guid': 18, 'text_a': 'NCCNc1nc(-c2ccc3[nH]ncc3c2)nc2ccccc12', 'text_b': None, 'label': 1},
#  {'guid': 20, 'text_a': 'COc1c(F)cc(-c2cnc3[nH]ccc3c2-c2ccc(N3CCN(C)CC3)cc2)cc1F', 'text_b': None, 'label': 0},
#  {'guid': 21, 'text_a': 'c1cc2c(cc1CN1CCCC(Nc3ccc4[nH]ncc4c3)C1)OCCO2', 'text_b': None, 'label': 0},
#  {'guid': 22, 'text_a': 'COCCCn1c(NC(=O)c2ccno2)nc2cc(CNC3CCCCC3)ccc21', 'text_b': None, 'label': 1},
#  {'guid': 23, 'text_a': 'Cc1ccn2ncnc(Nc3ccc(OCc4cccc(F)c4)c(Cl)c3)c12', 'text_b': None, 'label': 0},
#  {'guid': 26, 'text_a': 'C=CS(=O)(=O)NCc1ccc(Nc2nc(Nc3ccccc3C(=O)NC)c3cc[nH]c3n2)c(OC)c1', 'text_b': None, 'label': 0},
#  {'guid': 27, 'text_a': 'CC(C)Oc1cnc(-c2c[nH]c3ccc(-c4nnc(N)s4)cc23)cn1', 'text_b': None, 'label': 0},
#  {'guid': 28, 'text_a': 'CC(C)(O)C#Cc1ccc2c(c1)-c1nc(C(N)=O)c(CN3CCCC3)n1CCO2', 'text_b': None, 'label': 0},
#  {'guid': 32, 'text_a': 'Nc1n[nH]c2cccc(-c3ccc(NC(=S)Nc4ccc(Cl)cc4Cl)cc3)c12', 'text_b': None, 'label': 1},
#  {'guid': 36, 'text_a': 'O=C(N[C@H]1CCc2ccccc2NC1=O)c1n[nH]c(Cc2ccccc2)n1', 'text_b': None, 'label': 1},
#  {'guid': 39, 'text_a': 'COc1cccc(N(CCO)C(=O)Nc2ccc(-c3ncnc4[nH]cc(C)c34)cc2)c1', 'text_b': None, 'label': 0},
#  {'guid': 40, 'text_a': 'Cc1cccc(-n2nccc2-c2ccc3nc[nH]c(=O)c3c2)n1', 'text_b': None, 'label': 1},
#  {'guid': 41, 'text_a': 'COc1ccc(F)cc1-c1ccnc2[nH]c(C3CCCN3)cc12', 'text_b': None, 'label': 0},
#  {'guid': 42, 'text_a': 'COc1cccc(OC)c1CNC(=O)c1ccc2c(c1)/C(=N/Nc1ccc(S(N)(=O)=O)cc1)C(=O)N2', 'text_b': None, 'label': 1},
#  {'guid': 45, 'text_a': 'CS(=O)(=O)Nc1cc(-c2ccc(O)cc2)cc2[nH]ncc12', 'text_b': None, 'label': 1},
#  {'guid': 49, 'text_a': 'COc1ccc(F)cc1-c1cc(NC(=O)Cc2ccncc2)ncn1', 'text_b': None, 'label': 1},
#  {'guid': 52, 'text_a': 'N#Cc1cccc(C[C@H](N)COc2cncc(/C=C/c3ccncc3)c2)c1', 'text_b': None, 'label': 0},
#  {'guid': 53, 'text_a': 'CC(CN(C)C)Cn1cc(-c2cncc(-c3ccsc3)c2)c2ccccc21', 'text_b': None, 'label': 1},
#  {'guid': 57, 'text_a': 'COc1cc(Nc2nccc(Nc3cnc4ccccc4c3)n2)ccc1N1CCOCC1', 'text_b': None, 'label': 1},
#  {'guid': 59, 'text_a': 'Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4ccccc4)c3)cc12', 'text_b': None, 'label': 0},
#  {'guid': 63, 'text_a': 'O=C(Nc1ccc(-c2cccnc2)cc1)Nc1ccc(OC(F)(F)F)cc1Br', 'text_b': None, 'label': 1},
#  {'guid': 75, 'text_a': 'Clc1cc(Cl)cc(CNc2nccc(-c3ccc4c(c3)OCO4)n2)c1', 'text_b': None, 'label': 1},
#  {'guid': 76, 'text_a': 'Nc1nc2ccc(C(=O)c3c(F)cccc3Cl)cc2n1Cc1c(F)cccc1F', 'text_b': None, 'label': 0},
#  {'guid': 77, 'text_a': 'CS(=O)(=O)Nc1ccc2ccc3ncc(-c4cncnc4)cc3c(=O)c2c1', 'text_b': None, 'label': 0},
#  {'guid': 79, 'text_a': 'COC1(NC(=O)c2ccc(-c3cnc4c(NCCC(F)(F)F)nc(C#CCO)cn34)cc2C)CC1', 'text_b': None, 'label': 0},
#  {'guid': 82, 'text_a': 'C=CC(=O)Nc1ccc(-n2c(=O)ccc3oc4ccc(-c5cccnc5)cc4c32)cc1', 'text_b': None, 'label': 0},
#  {'guid': 86, 'text_a': 'CC(C)S(=O)(=O)c1ccccc1Nc1nc(Nc2nc3c(s2)CCN(C)CC3)ncc1Cl', 'text_b': None, 'label': 0},
#  {'guid': 90, 'text_a': 'CCCC(=O)Nc1n[nH]c2cc(Cl)c(-c3ccc(F)cc3)cc12', 'text_b': None, 'label': 0},
#  {'guid': 101, 'text_a': 'C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)C1CCCN1C(=O)CC', 'text_b': None, 'label': 0},
#  {'guid': 113, 'text_a': 'Cc1cc(-n2ccnc2)cc2[nH]c(-c3c(NCC(O)c4ccc(F)c(Cl)c4)cc[nH]c3=O)nc12', 'text_b': None, 'label': 0},
#  {'guid': 115, 'text_a': 'COc1ccc2c(c1CN1CCNCC1)O/C(=C\\c1c[nH]c3cnccc13)C2=O', 'text_b': None, 'label': 1},
#  {'guid': 120, 'text_a': 'CC(C)C(C/C=C1\\CC(CO)(COC(=O)C2CCCCC2)OC1=O)C(C)C', 'text_b': None, 'label': 1},
#  {'guid': 124, 'text_a': 'COCCn1nc2c(c1C1CC1)-c1nc(Nc3ccc(C(=O)NC4CCN(C)CC4)cc3OC)ncc1CC2', 'text_b': None, 'label': 0},
#  {'guid': 125, 'text_a': 'Cn1nc(C(C)(C)C)cc1NC(=O)c1cc(Cl)cc(Nc2ncnc3cnc(N4CCCC4)nc23)c1Cl', 'text_b': None, 'label': 0},
#  {'guid': 126, 'text_a': 'CN1CCN(c2cnc3cc(C(F)(F)F)cc(NCc4nnc5ccc(-c6cccs6)nn45)c3n2)CC1', 'text_b': None, 'label': 0},
#  {'guid': 128, 'text_a': 'COc1cc(N2CCN(C)CC2)ccc1Nc1nccc(-c2cn(C)c3c(C)nccc23)n1', 'text_b': None, 'label': 0},
#  {'guid': 133, 'text_a': 'CC(C)(C)n1nc(-c2ccc3ccccc3c2)c(C(N)=O)c1N', 'text_b': None, 'label': 1},
#  {'guid': 139, 'text_a': 'NCCNc1[nH]nc(N)c1-c1nc2ccccc2s1', 'text_b': None, 'label': 1},
#  {'guid': 140, 'text_a': 'COc1ccnc(C(=O)Nc2cncc(C(=O)c3cn(C(C)C)c4ncncc34)c2)c1', 'text_b': None, 'label': 1},
#  {'guid': 141, 'text_a': 'O=C(CN1CN(c2ccccc2)C2(CCN(C(=O)c3cnc4[nH]ncc4c3)CC2)C1=O)NCC(F)(F)F', 'text_b': None, 'label': 1},
#  {'guid': 146, 'text_a': 'OCCNCc1ccc2c(c1)-c1[nH]nc(-c3ccc(-c4ccc(O)cc4)cc3)c1C2', 'text_b': None, 'label': 1},
#  {'guid': 147, 'text_a': 'Cc1ccc2nc(NC(=O)Cc3csc(NC(=O)Nc4cccc(Cl)c4)n3)sc2c1', 'text_b': None, 'label': 1},
#  {'guid': 149, 'text_a': 'CNC(=O)c1nc2ccc(CCNC(=O)Nc3cc(C(F)(F)F)ccc3OC)cc2[nH]1', 'text_b': None, 'label': 0},
#  {'guid': 150, 'text_a': 'CC(C)(C)C(=O)N1N=CCC1c1cccc(Cl)c1', 'text_b': None, 'label': 1},
#  {'guid': 152, 'text_a': 'N#Cc1cccc(-c2c[nH]c3ncnc(N4CCOCC4)c23)c1', 'text_b': None, 'label': 1},
#  {'guid': 153, 'text_a': 'N#Cc1cnn2c(Nc3ccccc3)nc(Nc3ncc[nH]3)nc12', 'text_b': None, 'label': 1},
#  {'guid': 158, 'text_a': 'O[C@H]1CC[C@H](Nc2ccc3nnn(-c4cccc(OC(F)(F)F)c4)c3n2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 170, 'text_a': 'O=C(Cc1cccc(O)c1)Nc1nc(-c2ccncc2)cs1', 'text_b': None, 'label': 1},
#  {'guid': 171, 'text_a': 'CCc1cc(-c2c[nH]c3ncc(-c4cnn(CC(C)C)c4)cc23)nc(N)n1', 'text_b': None, 'label': 0},
#  {'guid': 172, 'text_a': 'COc1ccc(-c2c[nH]c(C(=O)c3cnn(-c4ccc5[nH]c(C)nc5c4)c3N)c2)cc1', 'text_b': None, 'label': 0},
#  {'guid': 173, 'text_a': 'O=C(CO)N1CCCC12CCCN(c1ncnc3[nH]ccc13)C2', 'text_b': None, 'label': 1},
#  {'guid': 175, 'text_a': 'COCc1ccc(-c2ccc3nnc(C(N)=O)c(N[C@@H](C)c4ccn(C)n4)c3c2)cn1', 'text_b': None, 'label': 0},
#  {'guid': 179, 'text_a': 'CC(C)(Nc1ccc(Cl)c(C(=O)O)c1)C(=O)Nc1nc2c(C(F)(F)F)cc3[nH]ncc3c2s1', 'text_b': None, 'label': 1},
#  {'guid': 183, 'text_a': 'CC(C)(C)c1cc(NC(=O)Nc2cccc3ccccc23)n(-c2cccc(N)c2)n1', 'text_b': None, 'label': 1},
#  {'guid': 188, 'text_a': 'O=C(CC1CNC(=O)c2cc(-c3cn[nH]c3)cn21)NCc1cccc(F)c1', 'text_b': None, 'label': 0},
#  {'guid': 192, 'text_a': 'Cc1cncc2cccc(S(=O)(=O)N3CCCNC[C@@H]3C)c12', 'text_b': None, 'label': 1},
#  {'guid': 195, 'text_a': 'CN(C)C(=O)CN1CC=C(c2[nH]c3nccc4c3c2CN(C)c2ccccc2-4)CC1', 'text_b': None, 'label': 0},
#  {'guid': 196, 'text_a': 'Cn1ncc2c(Oc3ccc4c(c3)nc(Nc3ccc(Cl)c(C(F)(F)F)c3)n4C)ncnc21', 'text_b': None, 'label': 0},
#  {'guid': 197, 'text_a': 'O=C(Nc1cccc(Nc2ccc3c(c2)CCCCC3=O)c1)c1ccccc1', 'text_b': None, 'label': 1},
#  {'guid': 200, 'text_a': 'CC(C)n1cc(C(=O)c2cncc(NC(=O)Cc3cn4cc(Cl)ccc4n3)c2)c2cncnc21', 'text_b': None, 'label': 1},
#  {'guid': 201, 'text_a': 'O=C1NC(=O)C(c2ccccc2Cl)=C1Nc1ccc(Cl)c(C(=O)O)c1', 'text_b': None, 'label': 1},
#  {'guid': 203, 'text_a': 'C[C@H]1[C@@H]2C[C@@]3(O[C@H](CCC3(C)C)CC(=O)O[C@@H](CO)CC(=O)O2)O[C@@H]1CCCCc1cccc(O)c1', 'text_b': None, 'label': 1},
#  {'guid': 208, 'text_a': 'N#Cc1ncc2nc1OCCCCOc1cc(P(=O)(O)O)c(Cl)cc1NC(=O)N2', 'text_b': None, 'label': 1},
#  {'guid': 209, 'text_a': 'CCN(CC)CCNC(=O)c1cccc(-c2cnc3ccc(-c4ccccc4)nn23)c1', 'text_b': None, 'label': 1},
#  {'guid': 213, 'text_a': 'Cc1ccc(NC(=O)Nc2ccc(NC(=O)c3cccc4onc(N)c34)cc2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 214, 'text_a': 'Cn1cc(/C=C2\\C(=O)NN=C2c2cnns2)c2c(Br)cccc21', 'text_b': None, 'label': 1},
#  {'guid': 216, 'text_a': 'Cc1ccc(NC(=O)c2cccc(C(F)(F)F)c2)cc1/C=C/n1cnc2c(Nc3ccncc3)ncnc21', 'text_b': None, 'label': 0},
#  {'guid': 224, 'text_a': 'Nc1nccc(-n2cc(-c3ccoc3)c3cnccc32)n1', 'text_b': None, 'label': 1},
#  {'guid': 229, 'text_a': 'COc1ccc2c(c1)[nH]c1c3c(OC)cncc3cc(C#N)c21', 'text_b': None, 'label': 1},
#  {'guid': 232, 'text_a': 'NCCc1ccc(-c2c(O)cc(Br)c3[nH]c(=O)c4sccc4c23)cc1', 'text_b': None, 'label': 1},
#  {'guid': 235, 'text_a': 'COc1ccccc1Nc1ncc(Br)c(Nc2cc(C3CC3)n[nH]2)n1', 'text_b': None, 'label': 1},
#  {'guid': 239, 'text_a': 'Cc1ccc2c(c1)c(/C=C1\\C(=O)NN=C1c1cnns1)cn2C', 'text_b': None, 'label': 1},
#  {'guid': 240, 'text_a': 'CCCCCCCCCCCCOc1cccc2c1C(=O)O[C@]2(CO)COC(=O)C(C(C)(C)C)C(C)(C)C', 'text_b': None, 'label': 1},
#  {'guid': 241, 'text_a': 'CN1CCC(NC(=O)c2cnc(Nc3cc(Cl)cc(Cl)c3)nc2N[C@@H]2COC[C@H]2O)CC1', 'text_b': None, 'label': 0},
#  {'guid': 242, 'text_a': 'O[C@H]1CC[C@H](Nc2nccc(-n3ncc4ccccc43)n2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 243, 'text_a': 'COc1ccc(Cn2ncc(NC(=O)c3cc(NC(=O)c4cc(N5CCN(C)CC5)cc(C(F)(F)F)c4)ccc3C)c2N)cc1', 'text_b': None, 'label': 0},
#  {'guid': 250, 'text_a': 'COc1cc2c(Oc3ccc(-c4nc5ccccc5s4)cc3F)ncnc2cc1OCCCN1CCN(C)CC1', 'text_b': None, 'label': 0},
#  {'guid': 254, 'text_a': 'Cn1c2ccccc2c2c3c(c4c5ccccc5n(CCC#N)c4c21)CNC3=O', 'text_b': None, 'label': 1},
#  {'guid': 256, 'text_a': 'CCN1CC(C)(C)Oc2nc(N3CC4CCC(C3)O4)nc(-c3ccc(NC(=O)Nc4ccnc(N5CCC(F)(F)CC5)c4)c(F)c3)c2C1=O', 'text_b': None, 'label': 0},
#  {'guid': 266, 'text_a': 'Cn1ccc(-c2cc(Nc3ccc(-n4cnc(-c5ccccn5)n4)cc3)ncc2F)n1', 'text_b': None, 'label': 0},
#  {'guid': 273, 'text_a': 'CCNC(=O)O[C@@H]1CC[C@@H]2C(C(=O)Nc3ccc(N(C)C)cc3)C[C@H]1N2Cc1ccccc1', 'text_b': None, 'label': 0},
#  {'guid': 274, 'text_a': 'O=c1[nH]c2ncc(-c3ccc(-c4cnc[nH]4)cc3)nc2n1CC1CCOCC1', 'text_b': None, 'label': 0},
#  {'guid': 276, 'text_a': 'Oc1ccc(-c2ccc(-c3cc(Nc4ccccc4)n[nH]3)cc2)c(O)c1', 'text_b': None, 'label': 1},
#  {'guid': 277, 'text_a': 'COC(=O)c1c[nH]c(-c2cc(Sc3ccc(NC(=O)Nc4cc(C)ccc4F)cc3)ccn2)c1', 'text_b': None, 'label': 0},
#  {'guid': 279, 'text_a': 'Cc1nc(N)ccc1-c1ccc(N(Cc2cccnc2)C(=O)c2ccc(O)cc2O)cc1', 'text_b': None, 'label': 1},
#  {'guid': 281, 'text_a': 'Cc1cc(OCc2ccc(F)cc2F)c(Br)c(=O)n1Cc1cccc(CN(C)C)c1', 'text_b': None, 'label': 1},
#  {'guid': 283, 'text_a': 'NCCNc1nc(-c2cn[nH]c2)nc2sc3c(c12)CCCC3', 'text_b': None, 'label': 1},
#  {'guid': 284, 'text_a': '[O-][n+]1ccc2c(-c3ccccc3Cl)cc(N3CCNCC3)nc2c1-c1c(Cl)cccc1Cl', 'text_b': None, 'label': 1},
#  {'guid': 289, 'text_a': 'Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCOCC2)n1', 'text_b': None, 'label': 1},
#  {'guid': 292, 'text_a': 'FC(F)(F)c1ccc(-c2cccn3nc(Nc4cnn(CCN5CCCC5)c4)nc23)cc1', 'text_b': None, 'label': 0},
#  {'guid': 298, 'text_a': 'O=c1c(Br)c(OCc2ccc(F)cc2F)cc(CN2CCOCC2)n1-c1c(F)cccc1F', 'text_b': None, 'label': 1},
#  {'guid': 300, 'text_a': 'CCc1nc(CNc2cc(Cl)c3ncc(C#N)c(Nc4ccc(F)c(Cl)c4)c3c2)c(C)[nH]1', 'text_b': None, 'label': 0},
#  {'guid': 307, 'text_a': 'CC(C)Oc1cc(N2CCOCC2)nc2c(-c3ccc[nH]3)nccc12', 'text_b': None, 'label': 0},
#  {'guid': 308, 'text_a': 'CN(c1ncnc2[nH]ccc12)[C@H]1CN(C(=O)Nc2ccc(Cl)cc2Cl)CC12CC2', 'text_b': None, 'label': 0},
#  {'guid': 315, 'text_a': 'COc1cc2ncn(-c3cc(OCc4sccc4Cl)c(C(N)=O)s3)c2cc1OC', 'text_b': None, 'label': 1},
#  {'guid': 319, 'text_a': 'COc1n[nH]c2ccc(C3C(C#N)=C(C)N=C(C)C3C#N)cc12', 'text_b': None, 'label': 1},
#  {'guid': 323, 'text_a': 'CN(C)C1CCN(c2cc(-c3c(N)nn4cccnc34)ncn2)C1', 'text_b': None, 'label': 0},
#  {'guid': 327, 'text_a': 'Cc1n[nH]cc1-c1cc2nc([C@]3(C)CCCN3)[nH]c(=O)c2s1.Cl.Cl', 'text_b': None, 'label': 0},
#  {'guid': 328, 'text_a': 'COc1cc(OC)cc(N(CC#Cc2nccnc2Cl)c2ccc3ncc(-c4cnn(C)c4)nc3c2)c1', 'text_b': None, 'label': 0},
#  {'guid': 331, 'text_a': 'CC(C)n1cnnc1-c1cccc(NC(=O)c2ccn(C)n2)n1', 'text_b': None, 'label': 1},
#  {'guid': 332, 'text_a': 'Cc1n[nH]cc1C(=O)Nc1cncc(C(=O)c2cn(C(C)C)c3ncncc23)c1', 'text_b': None, 'label': 0},
#  {'guid': 334, 'text_a': 'CN(Cc1cccs1)C(=O)c1ccc(N(Cc2ccccc2)C(=O)c2ccc(O)cc2O)cc1', 'text_b': None, 'label': 1},
#  {'guid': 338, 'text_a': 'Nc1ncc(-c2cnn(C3CCNCC3)c2)cc1-c1nc2ccc(-c3ccc4[nH]ncc4c3)cc2o1', 'text_b': None, 'label': 0},
#  {'guid': 344, 'text_a': 'O=C(Cc1ccc(-c2n[nH]c(=O)c3ccccc23)cc1)Nc1nc2ccccc2o1', 'text_b': None, 'label': 1},
#  {'guid': 352, 'text_a': 'O=C1NC(C2CC2)Cc2[nH]c(-c3ccncc3)cc21', 'text_b': None, 'label': 1},
#  {'guid': 356, 'text_a': 'Cc1ccncc1-c1ccc2c(C#N)c(N)ncc2c1', 'text_b': None, 'label': 1},
#  {'guid': 361, 'text_a': 'CN(C(=O)c1ccccc1)c1ccc2c(c1)[nH]/c(=N\\C(=O)c1ccc(OCc3ccccc3)s1)n2CCC(N)=O', 'text_b': None, 'label': 1},
#  {'guid': 364, 'text_a': 'Cc1cc2n[nH]c(=O)n2c2cc(-c3cnccn3)ccc12', 'text_b': None, 'label': 0},
#  {'guid': 367, 'text_a': 'Oc1cc(CN2CCCC(Nc3ccc4[nH]ncc4c3)C2)ccc1I', 'text_b': None, 'label': 0},
#  {'guid': 368, 'text_a': 'O=C(c1cccc2[nH]ccc12)N1CCc2c(cnn2-c2ccccc2Cl)C1', 'text_b': None, 'label': 1},
#  {'guid': 370, 'text_a': 'Cn1nc(C(=O)Nc2cnn3ccc(N4CCC[C@@H]4c4cccc(F)c4)nc23)ccc1=O', 'text_b': None, 'label': 1},
#  {'guid': 373, 'text_a': 'Cc1ncnc(Nc2ccc(OCc3cccc(F)c3)c(Cl)c2)c1/C=C/c1ccc(CN2CCOCC2)cc1', 'text_b': None, 'label': 0},
#  {'guid': 380, 'text_a': 'C[C@H]1CCc2cc(-c3nc(Cl)nc4ccsc34)ccc2N1C(=O)c1ccc(O)cc1O', 'text_b': None, 'label': 0},
#  {'guid': 384, 'text_a': 'Cc1nc2[nH]cc(C(=O)NC(C)(C)C)c2nc1Nc1cnn(C)c1', 'text_b': None, 'label': 0},
#  {'guid': 392, 'text_a': 'CC(C)(C)c1ccc(CC2(N)CCN(c3ccnc4[nH]ccc34)CC2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 401, 'text_a': 'Cc1cc(Nc2nccc(C(F)(F)C(F)(F)F)n2)cc(-c2cnc(C3(O)CCC(C(=O)OC(C)(C)C)CC3)s2)c1', 'text_b': None, 'label': 0},
#  {'guid': 405, 'text_a': 'Cc1ccc(-n2c(=O)ccc3ccc4ccc(-c5cnn(C)c5)cc4c32)cc1NC(=O)/C=C/CN(C)C', 'text_b': None, 'label': 0},
#  {'guid': 410, 'text_a': 'Cc1cc(N2CCNCC2)cnc1Nc1ncc2c3ccncc3n(C3CCCC3)c2n1', 'text_b': None, 'label': 0},
#  {'guid': 411, 'text_a': 'CN(C)c1ccc(/C=C2\\SC(=O)NC2=O)cc1', 'text_b': None, 'label': 1},
#  {'guid': 413, 'text_a': 'CC1(C)OC[C@@H](COc2ccc3c(c2)C(=O)c2ccc(Nc4ccccc4N)cc2CC3)O1', 'text_b': None, 'label': 1},
#  {'guid': 414, 'text_a': 'COc1cc2ncn(-c3cc(OCC4CCCC4)c(C(N)=O)s3)c2cc1OC', 'text_b': None, 'label': 1},
#  {'guid': 415, 'text_a': 'CCNC(=O)Nc1ccc2ncc(-c3ccc(OCCCN4CCOCC4)cc3)nc2n1', 'text_b': None, 'label': 0},
#  {'guid': 416, 'text_a': 'N#CCC(=O)N/N=C1\\C(=O)Nc2ccc(S(=O)(=O)N3CCOCC3)cc21', 'text_b': None, 'label': 1},
#  {'guid': 417, 'text_a': 'CC(C)C(=O)Nc1ccc(Cl)c(Nc2ncc(Br)c(Nc3cc(C4CC4)n[nH]3)n2)c1', 'text_b': None, 'label': 0},
#  {'guid': 420, 'text_a': 'COc1cc(Nc2ncc3c(C)nc(-c4cccc(Br)c4)n3n2)cc(OC)c1OC', 'text_b': None, 'label': 1},
#  {'guid': 421, 'text_a': 'O=C1CCCCN1c1n[nH]c2cnc(-c3cccnc3)cc12', 'text_b': None, 'label': 0},
#  {'guid': 425, 'text_a': 'C[C@H]1COCCN1c1nc(N2CCOC[C@@H]2C)c2ccc(-c3cccc(S(N)(=O)=O)c3)nc2n1', 'text_b': None, 'label': 1},
#  {'guid': 431, 'text_a': 'COC[C@@H](NC(=O)Nc1cc2[nH]nc(N3CC(OC)C3)c2cn1)c1ccccc1', 'text_b': None, 'label': 0},
#  {'guid': 432, 'text_a': 'CN(C)CCOc1ccc(-c2nc(-c3ccc(Oc4ccccc4)cc3)c3c(N)nccn23)cc1', 'text_b': None, 'label': 1},
#  {'guid': 435, 'text_a': 'Cn1cc(/C=C2\\C(=O)NN=C2c2nccs2)c2cc(Cl)ccc21', 'text_b': None, 'label': 1},
#  {'guid': 436, 'text_a': 'O=C1c2ccccc2C(O)(c2ccc3[nH]c(NC(=O)C(O)(C(F)(F)F)C(F)(F)F)nc3c2)N1Cc1ccccc1', 'text_b': None, 'label': 0},
#  {'guid': 437, 'text_a': 'CC(=O)Nc1ccc(Sc2nccc(Nc3cc(C)[nH]n3)n2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 438, 'text_a': 'Nc1cc(-c2ccc3c(-c4ccc(N5CCNCC5)cc4)n[nH]c3n2)ccn1', 'text_b': None, 'label': 0},
#  {'guid': 439, 'text_a': 'CC(C)(C)c1cc(C(=O)N2CCNC(=O)C2)c(NC(=O)Nc2ccc(Cl)cc2)s1', 'text_b': None, 'label': 1},
#  {'guid': 450, 'text_a': 'CN(C)CCn1cnc2cnc3ccc(C#CCNC(=O)c4cccn(Cc5ccccc5)c4=O)cc3c21', 'text_b': None, 'label': 0},
#  {'guid': 453, 'text_a': 'CCN1CCN(c2ccc(-c3cc4ncn(C)c(=O)c4c(NC(C)C)n3)cc2S(C)(=O)=O)CC1', 'text_b': None, 'label': 0},
#  {'guid': 455, 'text_a': 'O=C(Nc1cccc(Oc2cccc3[nH]c(=O)[nH]c23)c1)c1cccc(-n2cccc2)c1', 'text_b': None, 'label': 1},
#  {'guid': 460, 'text_a': 'COc1cc(OC2CCNCC2)c2c(Nc3ccc(F)c(Cl)c3)ncnc2c1', 'text_b': None, 'label': 1},
#  {'guid': 461, 'text_a': 'C[C@@H]1C[C@H](c2ccncc2NC(=O)c2ccc(F)c(-c3c(F)cccc3F)n2)C[C@H](N)C12OCCO2', 'text_b': None, 'label': 0},
#  {'guid': 463, 'text_a': 'C[C@H](CO)n1c(=O)n(C)c2cnc3ccc(-c4cnn(C)c4)nc3c21', 'text_b': None, 'label': 0},
#  {'guid': 464, 'text_a': 'CC(C)n1nc(-c2ccc3[nH]ccc3c2)c2c(N)ncnc21', 'text_b': None, 'label': 1},
#  {'guid': 465, 'text_a': 'CC1CCCCN1c1ccc2nnnc(Nc3cccc(OC(F)(F)F)c3)c2n1', 'text_b': None, 'label': 0},
#  {'guid': 468, 'text_a': 'COc1cc(Nc2nccc(Nc3ccc4[nH]ncc4c3)n2)cc(OC)c1OC', 'text_b': None, 'label': 1},
#  {'guid': 469, 'text_a': 'Cc1cc(NC(=O)Nc2ccc(-c3ccnc4[nH]nc(C)c34)cc2)ccc1N1CCN(C)CC1', 'text_b': None, 'label': 0},
#  {'guid': 474, 'text_a': 'c1cnc(CCc2ccncc2)c(-c2nnc(NCc3ccc4c(c3)OCO4)o2)c1', 'text_b': None, 'label': 1},
#  {'guid': 475, 'text_a': 'Nc1ncc(-c2cc(C3CCN(C4COC4)CC3)n(C3CCOC3)n2)cc1C(F)(F)F', 'text_b': None, 'label': 0},
#  {'guid': 476, 'text_a': 'C=CC(=O)NC1CCC(n2c(NC(=O)c3cccc(C(F)(F)F)c3)nc3cc(C)ccc32)C1', 'text_b': None, 'label': 0},
#  {'guid': 481, 'text_a': 'CNS(=O)(=O)c1cccc(Nc2ncnc3[nH]c4ccccc4c23)c1', 'text_b': None, 'label': 1},
#  {'guid': 482, 'text_a': 'Nc1n[nH]c2cc(-c3ccc(C(=O)NCCNC(=O)c4ccc(Cl)c(C(F)(F)F)c4)cc3)ccc12', 'text_b': None, 'label': 0},
#  {'guid': 488, 'text_a': 'CC(CNC(=O)Nc1cc2[nH]nc(N)c2cn1)c1ccccc1', 'text_b': None, 'label': 1},
#  {'guid': 489, 'text_a': 'COc1cc(N2CCN(C(C)=O)CC2)ccc1Nc1ncc(C(F)(F)F)c(Nc2ccc(N3CCN(C(=O)OC(C)(C)C)CC3)cc2OC)n1', 'text_b': None, 'label': 0},
#  {'guid': 491, 'text_a': 'Fc1cccc(-n2cnc3c(NCc4ccccc4F)nc(N4CCOCC4)nc32)c1', 'text_b': None, 'label': 1},
#  {'guid': 493, 'text_a': 'COc1cc(OC)cc(-c2cc3cnc(N(CCCCOCc4ccccc4)C(C)=O)cc3nc2NC(=O)NC(C)(C)C)c1', 'text_b': None, 'label': 0},
#  {'guid': 498, 'text_a': 'CN1CCN(C(=O)c2ccc(NC(=O)c3csc4c(=O)[nH]cnc34)c(F)c2)CC1', 'text_b': None, 'label': 0},
#  {'guid': 500, 'text_a': 'CCO/N=C/c1c(N)ncnc1N1CCN(C(=O)Nc2ccc(OC(C)C)cc2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 506, 'text_a': 'COc1ncc(Nc2ncc([C@@H](C)N3CCN(S(C)(=O)=O)CC3)cc2-c2nc(C)nc(N)n2)cc1F', 'text_b': None, 'label': 0},
#  {'guid': 511, 'text_a': 'NCC1CCn2c(c(C3=C(c4c[nH]c5ccccc45)C(=O)NC3=O)c3ccccc32)C1', 'text_b': None, 'label': 1},
#  {'guid': 518, 'text_a': 'Cc1nc2cc(-c3ccccc3)c(-c3ccc(C4(N)CCC4)cc3)nn2c1-c1cn[nH]c1', 'text_b': None, 'label': 0},
#  {'guid': 520, 'text_a': 'CC1(Nc2nc(-c3cncs3)nc3cnccc23)CC1', 'text_b': None, 'label': 0},
#  {'guid': 528, 'text_a': 'O=C1NC(=O)C2=C1c1cn(c3ccccc13)CCCc1ccc(c(N3CCCC3)n1)CCCn1cc2c2ccccc21', 'text_b': None, 'label': 1},
#  {'guid': 531, 'text_a': 'COc1ccc(-c2nc3cc(-c4csc(C(=O)O)c4)cnc3[nH]2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 533, 'text_a': 'CS(=O)(=O)Nc1cccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)c1', 'text_b': None, 'label': 1},
#  {'guid': 536, 'text_a': 'CCS(=O)(=O)Nc1cc(-c2ccc3ncnc(Nc4cccc(C(=O)OC)c4)c3c2)cnc1OC', 'text_b': None, 'label': 0},
#  {'guid': 539, 'text_a': 'O=C1/C(=C/c2c(F)cccc2F)CNC/C1=C\\c1c(F)cccc1F', 'text_b': None, 'label': 0},
#  {'guid': 541, 'text_a': 'Cc1ccc([N+](=O)[O-])cc1S(=O)(=O)N(CCO)/N=C/c1cnn2ccc(C#N)cc12', 'text_b': None, 'label': 0},
#  {'guid': 542, 'text_a': 'CN(C)c1ccc(/C=C/c2nc3c(Cc4ccccc4)c(Cc4ccccc4)ccc3[s+]2C)c2ccccc12', 'text_b': None, 'label': 1},
#  {'guid': 543, 'text_a': 'CCn1nc(C#Cc2cc(C(=O)Nc3ccc(CN4CCN(C)CC4)c(C(F)(F)F)c3)ccc2C(C)C)c2c(N)ncnc21', 'text_b': None, 'label': 0},
#  {'guid': 547, 'text_a': 'O=C1NCc2[nH]c3c(ccc4cnc(-c5ccccc5C(F)(F)F)cc43)c21', 'text_b': None, 'label': 0},
#  {'guid': 550, 'text_a': 'C[C@@H](O)c1nc2cnc3[nH]ccc3c2n1[C@H]1CCCOC1', 'text_b': None, 'label': 0},
#  {'guid': 560, 'text_a': 'Nc1cc2n[nH]c(=O)n2c2cc(-c3ccoc3)ccc12', 'text_b': None, 'label': 1},
#  {'guid': 562, 'text_a': 'CCCCCCc1ccc2nc(C(=O)N[C@@H](Cc3ccc(O)cc3)C(=O)OC)cc(C(=O)O)c2c1', 'text_b': None, 'label': 1},
#  {'guid': 563, 'text_a': 'CCC(=O)Nc1ccc(Sc2nc(C)cc(Nc3cc(C)[nH]n3)n2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 569, 'text_a': 'Nc1ncc(-c2cc(N3C[C@@H]4C[C@H]3CO4)nc(N3CCC3)n2)cc1C(F)(F)F', 'text_b': None, 'label': 0},
#  {'guid': 570, 'text_a': 'CCNC(=O)c1cn2ncnc(Nc3cc(NC(=O)c4cccc(-n5cccn5)c4)ccc3C)c2c1C', 'text_b': None, 'label': 0},
#  {'guid': 573, 'text_a': 'Brc1cccc(Nc2[nH]cnc3nc4ccccc4c2-3)c1', 'text_b': None, 'label': 1},
#  {'guid': 575, 'text_a': 'CC(C)(C)c1cc(NC(=O)Nc2ccc(Oc3ccnc(Nc4ccc5[nH]ccc5c4)n3)c3ccccc23)n(-c2ccc(O)cc2)n1', 'text_b': None, 'label': 0},
#  {'guid': 577, 'text_a': 'CNS(=O)(=O)c1ccc2ncnc(N3CCN(C(=O)[C@H](N)Cc4ccc(Cl)cc4)CC3)c2c1', 'text_b': None, 'label': 0},
#  {'guid': 579, 'text_a': 'CN1CCC(Nc2ccc(-c3n[nH]c4c3CN(S(=O)(=O)c3c(Cl)cccc3Cl)CC4)cc2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 580, 'text_a': 'CCCCCCn1cc2c3c(cccc31)N(C)[C@@H](C(C)C)C(=O)N[C@H](CO)C2', 'text_b': None, 'label': 1},
#  {'guid': 585, 'text_a': 'COc1cc2c(NC3=CC(=O)C(OCc4ccco4)=CC3=O)ncnc2cc1OCCCN1CCCC1', 'text_b': None, 'label': 1},
#  {'guid': 586, 'text_a': 'Oc1cc(-c2[nH]c(-c3ccco3)nc2-c2ccncc2)ccc1Cl', 'text_b': None, 'label': 1},
#  {'guid': 591, 'text_a': 'Cc1cncc(NC(=O)n2ccc3cc(Oc4ncnc5c4CCNC5)ccc32)c1', 'text_b': None, 'label': 0},
#  {'guid': 595, 'text_a': 'Cc1cc(C)c(NC(=O)c2ccc3nc(NC(=O)OC(C)(C)C)oc3c2)c(C)c1', 'text_b': None, 'label': 0},
#  {'guid': 596, 'text_a': 'CC(C)c1nsc(C(=O)Nc2ccc3ncnc(Nc4cccc(Br)c4)c3c2)n1', 'text_b': None, 'label': 0},
#  {'guid': 598, 'text_a': 'CNC(=O)c1cc(Oc2ccc(NC(=O)c3ccc(CN4CCN(C)CC4)cc3)cc2)ccn1', 'text_b': None, 'label': 0},
#  {'guid': 599, 'text_a': 'COc1ccc(C(=O)Nc2ncc(-c3ccc(C(=O)O)nn3)s2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 600, 'text_a': 'CCc1nn(Cc2cccc(C)n2)c2cccc(NC(=O)c3cnc4cc(CCN5CC[C@@H](F)C5)ccn34)c12', 'text_b': None, 'label': 0},
#  {'guid': 608, 'text_a': 'Cc1c(C(=O)O)sc2ncnc(Nc3ccc(F)cc3OC(C)CC(C)(C)O)c12', 'text_b': None, 'label': 1},
#  {'guid': 618, 'text_a': 'Cc1nc2cc(-n3ncc(C(=O)c4cc(Br)c(Br)[nH]4)c3N)ccc2[nH]1', 'text_b': None, 'label': 0},
#  {'guid': 633, 'text_a': 'CN(C)[C@H]1CC[C@H](Nc2ncnn3ccc([C@H]4CC[C@@H](C(N)=O)CC4)c23)CC1', 'text_b': None, 'label': 0},
#  {'guid': 657, 'text_a': 'COc1cc(C(=O)NCc2nc3ccccc3s2)ccc1-c1cn[nH]c1', 'text_b': None, 'label': 0},
#  {'guid': 664, 'text_a': 'COc1cc(F)ccc1-c1ccnc2[nH]c(C3CN(C)CCO3)cc12', 'text_b': None, 'label': 0},
#  {'guid': 667, 'text_a': 'Cc1ccc(C(=O)NC2CC2)cc1-c1ccc2c(OC(C)C)nncc2c1', 'text_b': None, 'label': 0},
#  {'guid': 668, 'text_a': '[C-]#[N+]c1ccc2nnc(COc3ccnc4cc(OC)ccc34)n2c1', 'text_b': None, 'label': 0},
#  {'guid': 669, 'text_a': 'c1ccc2c(N3CCNCC3)nc(-c3ccc4[nH]ncc4c3)nc2c1', 'text_b': None, 'label': 1},
#  {'guid': 671, 'text_a': 'O=C(O)c1cccc(-c2[nH]nc3cc(Nc4ccccc4Cl)ccc23)c1', 'text_b': None, 'label': 1},
#  {'guid': 676, 'text_a': 'COCCCn1cc(NC(=O)c2csc(-c3nncn3C(C)C)n2)cn1', 'text_b': None, 'label': 1},
#  {'guid': 678, 'text_a': 'COc1cc2c(cc1OC)-c1n[nH]c(-c3ccc(-c4c[nH]cn4)cc3)c1C2', 'text_b': None, 'label': 0},
#  {'guid': 682, 'text_a': 'COC(=O)c1cccc2nc(Nc3ccc(-c4nn([C@H]5CC[C@@H](N6CCN(C)CC6)CC5)c5ncnc(N)c45)cc3)oc12', 'text_b': None, 'label': 0},
#  {'guid': 684, 'text_a': 'C=CC(=O)Nc1ccc2ncnc(Nc3ccccc3)c2c1', 'text_b': None, 'label': 1},
#  {'guid': 687, 'text_a': 'NCCNC(=O)c1cc(-c2scc3c2OCCO3)cnc1N', 'text_b': None, 'label': 1},
#  {'guid': 688, 'text_a': 'OCc1cccc(-c2c[nH]c3ncnc(N4CCOCC4)c23)c1', 'text_b': None, 'label': 1},
#  {'guid': 689, 'text_a': 'CCc1ccc(C(=O)Nc2cc(CN3CCN(C)CC3)cc(C(F)(F)F)c2)cc1C#Cc1ccoc1', 'text_b': None, 'label': 0},
#  {'guid': 695, 'text_a': 'FC1(F)Oc2cccc(-c3cccn4nc(Nc5ccc6c(c5)CCNCC6)nc34)c2O1', 'text_b': None, 'label': 0},
#  {'guid': 696, 'text_a': 'C=CC(=O)N[C@H]1CCc2c(-c3ccc(Oc4ccccc4)cc3)c3c(N)ncnc3n2C1', 'text_b': None, 'label': 1},
#  {'guid': 698, 'text_a': 'Fc1cccc(F)c1-c1ccc2[nH]nc(-c3cncc(N4CCCCC4)n3)c2c1', 'text_b': None, 'label': 0},
#  {'guid': 699, 'text_a': 'NC(=O)c1cnc2[nH]ccc2c1N[C@H]1CCCN(Cc2ccccc2)C1', 'text_b': None, 'label': 0},
#  {'guid': 701, 'text_a': 'COc1cc2c(cc1-c1cnn3ccc(-c4ccnc5[nH]ccc45)cc13)CNC2', 'text_b': None, 'label': 0},
#  {'guid': 703, 'text_a': 'C[C@H](CO)n1c2cnccc2c2cnc(Nc3ccc(N4CC[C@@H](O)C4)cn3)nc21', 'text_b': None, 'label': 0},
#  {'guid': 706, 'text_a': 'O=C(C1CCOC1)N1N=CCC1c1ccccc1', 'text_b': None, 'label': 1},
#  {'guid': 707, 'text_a': 'C=CC(=O)Nc1cccc(Nc2nc(N/N=C(\\C)c3ccc(F)cc3)ncc2Cl)c1', 'text_b': None, 'label': 0},
#  {'guid': 708, 'text_a': 'CN1CCN(CCOc2cccc(CC(=O)Nc3nc(-c4ccncc4)cs3)c2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 713, 'text_a': 'CC(CO)NC(=O)c1cccc(-c2cc(Nc3cccc(N4CCCC4C)n3)c3nccn3n2)c1', 'text_b': None, 'label': 0},
#  {'guid': 719, 'text_a': 'CC(O)(C#Cc1ccc(N2CCCC2)c(Nc2ncnc3[nH]ccc23)c1)c1nccs1', 'text_b': None, 'label': 0},
#  {'guid': 720, 'text_a': 'CC(C)Cc1csc2nc(-c3ccncc3)nc(NCCN)c12', 'text_b': None, 'label': 1},
#  {'guid': 725, 'text_a': 'CN(C)C(=O)c1c(CNC(=O)c2ccc(N3CCCCC3)nc2)c(=O)c2ccc(Cl)cc2n1-c1ccccc1', 'text_b': None, 'label': 1},
#  {'guid': 728, 'text_a': 'Cc1cc(NC(=O)N2CCCC(c3nnn4cnc5[nH]ccc5c34)C2)sn1', 'text_b': None, 'label': 0},
#  {'guid': 729, 'text_a': 'CC(C)(C)CCN1CCN(c2ccc(Nc3ncc4cc5n(c4n3)C3(CCCC3)CNC5=O)nc2)CC1(C)C', 'text_b': None, 'label': 0},
#  {'guid': 733, 'text_a': 'O=C(Nc1cc(Cl)ccc1N1CCCC(CO)C1)c1cnn2nccnc12', 'text_b': None, 'label': 0},
#  {'guid': 734, 'text_a': 'Cc1nc2cccc(-c3cc4c([nH]3)CCNC4=O)c2nc1NC(=N)N', 'text_b': None, 'label': 0},
#  {'guid': 737, 'text_a': 'CN1CCc2cc(-c3cnc(N)c(-c4nnc(C5CC5)o4)c3)ccc21', 'text_b': None, 'label': 0},
#  {'guid': 740, 'text_a': 'CCc1cc2c(cc1N1CCOCC1)C(C)(C)c1[nH]c3nc(C(=O)N4CCOCC4)ccc3c1C2=O', 'text_b': None, 'label': 0},
#  {'guid': 742, 'text_a': 'CN1CCC(Oc2cccc3ncnc(Nc4ccc(OCc5ccccn5)cc4)c23)CC1', 'text_b': None, 'label': 1},
#  {'guid': 747, 'text_a': 'COc1cccc(-c2ccc3c(c2)Nc2ccc(CCC(=O)N(C)C)cc2NC3=O)c1', 'text_b': None, 'label': 1},
#  {'guid': 751, 'text_a': 'COC1C(CO)OC(n2c3c(Cl)cccc3c3c4c(c5c6cccc(Cl)c6[nH]c5c32)CNC4=O)C(O)C1O', 'text_b': None, 'label': 0},
#  {'guid': 753, 'text_a': 'CCN(CC)Cc1ccc(NC(=O)c2n[nH]cc2Nc2ncnc3sccc23)cc1', 'text_b': None, 'label': 1},
#  {'guid': 766, 'text_a': 'COc1ccc(-c2ccc3c(N4CCOC[C@@H]4C)nc(-n4ccnc4CO)nc3n2)cc1CO', 'text_b': None, 'label': 0},
#  {'guid': 769, 'text_a': 'CC1(CNC(=O)c2nc(-c3cccc(NS(C)(=O)=O)c3)cnc2N)CCNCC1', 'text_b': None, 'label': 0},
#  {'guid': 773, 'text_a': 'CCn1cc(C(=O)Nc2cccc(-c3nncn3C(C)C)n2)c(OC)n1', 'text_b': None, 'label': 1},
#  {'guid': 782, 'text_a': 'CC(C)(C)C(=O)N1N=CCC1c1ccc(Cl)cc1', 'text_b': None, 'label': 1},
#  {'guid': 784, 'text_a': 'CN(C)C(=O)CN1CCc2ccc(Nc3nc4c(-c5cccc6c5OC(F)(F)O6)cccn4n3)cc2CC1', 'text_b': None, 'label': 0},
#  {'guid': 787, 'text_a': 'NC(=O)c1ccc2[nH]c(-c3ccc(OCC4CCN(Cc5ccccc5)CC4)cc3)nc2c1', 'text_b': None, 'label': 1},
#  {'guid': 789, 'text_a': 'NC(=O)c1cccnc1OC1CC2(CC(Nc3nc4cc(F)c(Br)cc4s3)C2)C1', 'text_b': None, 'label': 0},
#  {'guid': 792, 'text_a': 'COc1cc(N2CCC(CCS(C)(=O)=O)CC2)c(C)cc1Nc1nccc(-c2c(-c3cccc(C(=O)Nc4c(F)cccc4F)c3)nc3ccccn23)n1', 'text_b': None, 'label': 0},
#  {'guid': 798, 'text_a': 'CN1CCN(c2ccc(Nc3nc4c(-c5ccc(C(F)(F)F)cc5)cccn4n3)cc2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 799, 'text_a': 'Cn1cncc1-c1cccc(-c2cccc3c(=O)cc(N4CCOCC4)oc23)c1', 'text_b': None, 'label': 0},
#  {'guid': 801, 'text_a': 'COc1ccc(C)cc1NC(=O)Nc1nnc(SCc2cc(=O)n3cccc(C)c3n2)s1', 'text_b': None, 'label': 1},
#  {'guid': 803, 'text_a': 'O=C1NC(=O)c2c1c(I)cc1[nH]c3ccc(O)cc3c21', 'text_b': None, 'label': 1},
#  {'guid': 804, 'text_a': 'O=S(=O)(Nc1ccc(F)c(C#Cc2ccc3[nH]ncc3c2)c1F)c1cccnc1', 'text_b': None, 'label': 0},
#  {'guid': 810, 'text_a': 'Cc1nc(O)c2c(ccc3[nH]c(Nc4c(Cl)cccc4Cl)nc32)c1C', 'text_b': None, 'label': 1},
#  {'guid': 813, 'text_a': 'N[C@H]1CCCN(c2ccc3ncc(-c4cccc(OC(F)(F)F)c4)n3n2)C1', 'text_b': None, 'label': 1},
#  {'guid': 815, 'text_a': 'Cc1cc(-c2n[nH]c3cc(NC(=O)N[C@H](c4ccc(F)cc4)C(F)(F)F)ncc23)ccn1', 'text_b': None, 'label': 0},
#  {'guid': 821, 'text_a': 'Cc1ccnc(Nc2nc3cccc(-c4cccc(C(C)C)c4)n3n2)c1', 'text_b': None, 'label': 1},
#  {'guid': 822, 'text_a': 'Cc1cccc2c1/C(=N/NC(=O)Cc1ccc(O)cc1)C(=O)N2', 'text_b': None, 'label': 1},
#  {'guid': 823, 'text_a': 'N#Cc1c[nH]c2nccc(-c3cccc(Cl)c3)c12', 'text_b': None, 'label': 1},
#  {'guid': 831, 'text_a': 'CCN(C(=O)c1ccc2c(c1)CCCC2)c1ccnc(N[C@@H](C)c2ccccc2)n1', 'text_b': None, 'label': 0},
#  {'guid': 837, 'text_a': 'NC1CCCC(C(=O)Nc2ccc3[nH]nc(Nc4cccc(C(F)(F)F)c4)c3c2)C1', 'text_b': None, 'label': 0},
#  {'guid': 838, 'text_a': 'CCN1CCN(Cc2cnc(Nc3ncnc(-c4cc(F)c5nc(C)n(C(C)C)c5c4)c3F)cn2)CC1', 'text_b': None, 'label': 0},
#  {'guid': 839, 'text_a': 'CN(C)Cc1ccc(NC(=O)c2cccc(CNC(=O)Nc3ccc(C(N)=O)cc3)c2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 843, 'text_a': 'CS(=O)(=O)N1CC=C(c2cc3c(-c4cccc(NCC5CC5)n4)ccnc3[nH]2)CC1', 'text_b': None, 'label': 0},
#  {'guid': 844, 'text_a': 'CC(C)Nc1cc(Nc2ccc3nsnc3c2)ncc1C(=O)NC[C@@H](F)C(C)(C)O', 'text_b': None, 'label': 0},
#  {'guid': 847, 'text_a': 'CC(C)n1cc(C(=O)c2cncc(NC(=O)c3cc4occc4cn3)c2)c2cncnc21', 'text_b': None, 'label': 0},
#  {'guid': 855, 'text_a': 'CN1CCC(c2cc(-c3ccc(F)cc3)c(-c3ccncc3)[nH]2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 859, 'text_a': 'CCN(CC)CCCNC(=O)CCc1ccc(Nc2ncc(Br)c(Nc3cc(C4CC4)[nH]n3)n2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 863, 'text_a': 'COc1cc(-c2ccc3nccc(Nc4cc(NS(C)(=O)=O)ccc4F)c3c2)ccc1O', 'text_b': None, 'label': 0},
#  {'guid': 865, 'text_a': 'CC(Cn1ncc2c(Nc3cccc(O)c3)nc(SCCN3CCOCC3)nc21)c1ccccc1.Cl', 'text_b': None, 'label': 1},
#  {'guid': 867, 'text_a': 'COc1cccc2c1CNC(C(=O)Nc1ccc(-c3cn[nH]c3)cc1OCCN(C)C)C2', 'text_b': None, 'label': 0},
#  {'guid': 868, 'text_a': 'O=C(COc1cc(F)c(F)c(F)c1)Nc1cccc(Oc2cc(Nc3ccc(OCc4cccc(F)c4)c(Cl)c3)ncn2)c1', 'text_b': None, 'label': 0},
#  {'guid': 869, 'text_a': 'S=C(Nc1cccnc1)Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1', 'text_b': None, 'label': 1},
#  {'guid': 870, 'text_a': 'COc1ccc2sc(C(=O)N(C)Cc3ccccc3)cc2c1', 'text_b': None, 'label': 1},
#  {'guid': 876, 'text_a': 'CCOc1cc2ncc(C#N)c(Nc3ccc(F)c(Cl)c3)c2cc1NC(=O)C(CSC(C)=O)CSC(C)=O', 'text_b': None, 'label': 0},
#  {'guid': 883, 'text_a': 'CCn1cnc2cc3c(N4CCN(/C(S)=N\\Cc5ccccc5)CC4)ncnc3cc21', 'text_b': None, 'label': 0},
#  {'guid': 891, 'text_a': 'Cc1cccc(-c2nn(CCC(=S)Nc3cccc(C#N)c3)cc2-c2ccc3ncccc3c2)n1', 'text_b': None, 'label': 0},
#  {'guid': 895, 'text_a': 'COc1cc(-c2cnn(C)c2)ccc1Nc1ncc2ccnc(C3CC3)c2n1', 'text_b': None, 'label': 0},
#  {'guid': 896, 'text_a': 'O=c1[nH]c(NC2CCC2)nc(N[C@@H]2C[C@H](CO)[C@@H](O)[C@H]2O)c1-c1cscn1', 'text_b': None, 'label': 0},
#  {'guid': 899, 'text_a': 'CC(C)(C)c1cc(NC(=O)Nc2cccc3ccccc23)n(-c2cccc(CNC(=O)CCC(=O)O)c2)n1', 'text_b': None, 'label': 1},
#  {'guid': 902, 'text_a': 'CNc1ncc2ncnc(Nc3ccccc3)c2n1', 'text_b': None, 'label': 1},
#  {'guid': 903, 'text_a': 'CCNC(=O)c1ccc(Nc2ncc(F)c(N3C[C@H]4CC[C@H](C3)N4C(=O)C3CC3)n2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 906, 'text_a': 'CCc1ccc2[nH]cc(C3=C(n4cc(CCNC)c5ccccc54)C(=O)NC3=O)c2c1', 'text_b': None, 'label': 0},
#  {'guid': 910, 'text_a': 'C[C@@H](NC(=O)Nc1cc2[nH]nc(NC3CCNCC3)c2cn1)c1ccccc1', 'text_b': None, 'label': 0},
#  {'guid': 917, 'text_a': 'Cc1cc(C(C)(O)C#Cc2cccc(-c3c[nH]c4cnc(N)nc34)c2)no1', 'text_b': None, 'label': 0},
#  {'guid': 918, 'text_a': 'Oc1cc(/C=C/C(=S)NCc2ccc(O)c(O)c2O)cc(Br)c1O', 'text_b': None, 'label': 1},
#  {'guid': 921, 'text_a': 'CCN(CC)CCCCNc1cc2nc(N)c(-c3cc(OC)cc(OC)c3)cc2cn1', 'text_b': None, 'label': 1},
#  {'guid': 924, 'text_a': 'O=C(Cc1nc(N2CCOCC2)cc(=O)[nH]1)Nc1cccc(Br)c1', 'text_b': None, 'label': 1},
#  {'guid': 931, 'text_a': 'CSC[C@@H](NC(=O)Nc1cc2[nH]nc(N)c2cn1)c1ccccc1', 'text_b': None, 'label': 1},
#  {'guid': 932, 'text_a': 'COc1cc(-c2ccc3c(c2)Nc2ccc(CC(=O)N(C)C)cc2NC3=O)ccc1[N+](=O)[O-]', 'text_b': None, 'label': 1},
#  {'guid': 938, 'text_a': 'CN(C)C(=O)c1cc2cnc(Nc3ccc(N4CCN(C(=O)OC(C)(C)C)CC4)nn3)nc2n1C1CCCC1', 'text_b': None, 'label': 0},
#  {'guid': 939, 'text_a': 'CCN1CC(C)(C)Oc2nc(N3CCOC[C@@H]3C)nc(-c3ccc(NC(=O)Nc4ccc(OC)nc4)c(C)c3)c2C1=O', 'text_b': None, 'label': 0},
#  {'guid': 940, 'text_a': 'CSc1c(Cl)nc(-c2ccc(NC(=O)Nc3ccc4oc(=O)[nH]c4c3)cc2)nc1N1CCOCC1', 'text_b': None, 'label': 0},
#  {'guid': 941, 'text_a': 'CCS(=O)(=O)N1CCc2cnc(NC3CCOCC3)nc2C1', 'text_b': None, 'label': 0},
#  {'guid': 946, 'text_a': 'NC(=O)C1(COc2ccn3c(-c4ccccc4)c(-c4ccc(C5(N)CCC5)cc4)nc3n2)CC1', 'text_b': None, 'label': 0},
#  {'guid': 948, 'text_a': 'COC(=O)c1[nH]c(C(C)(C)C)cc1NC(=O)Nc1cccc2ccccc12', 'text_b': None, 'label': 1},
#  {'guid': 950, 'text_a': 'O=C(c1cc(-c2[nH]ncc2-c2cccc(Cl)c2)c[nH]1)N1CCCC1', 'text_b': None, 'label': 0},
#  {'guid': 953, 'text_a': 'N#Cc1cnc2cc(OCCCN3CCOCC3)ccc2c1Nc1ccc(Oc2ccccc2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 954, 'text_a': 'Cc1cccc(-c2nc(N)sc2-c2ccc3ncccc3n2)n1', 'text_b': None, 'label': 1},
#  {'guid': 955, 'text_a': 'CC(C)(C)NC(=O)Nc1nc2cc(N)ncc2cc1-c1ccccc1', 'text_b': None, 'label': 0},
#  {'guid': 960, 'text_a': 'Cc1cccc(-c2cc(Nc3ccn(C)n3)nc3[nH]cc(C#N)c23)c1', 'text_b': None, 'label': 1},
#  {'guid': 961, 'text_a': 'CCN(CC)CC#CC(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2cn1', 'text_b': None, 'label': 0},
#  {'guid': 965, 'text_a': 'N#Cc1cc(-c2ccnc(Nc3cnn(CCn4cccn4)c3)c2)ccc1OC1CCOCC1', 'text_b': None, 'label': 0},
#  {'guid': 969, 'text_a': 'NC(=O)c1ccc2[nH]c(-c3ccc(S(=O)(=O)NCc4cccs4)cc3)nc2c1', 'text_b': None, 'label': 1},
#  {'guid': 974, 'text_a': 'CCCCCCCCC#Cc1ccc2c(c1)C[C@@H](CO)NC(=O)[C@H](C(C)C)N2C', 'text_b': None, 'label': 1},
#  {'guid': 976, 'text_a': 'COCCN1CCc2ccc(Nc3ncc(Cl)c(N[C@H]4CC[C@@H](NS(C)(=O)=O)CC4)n3)cc2CC1', 'text_b': None, 'label': 0},
#  {'guid': 979, 'text_a': 'COc1cc2c(Nc3ccc(Cl)c(Cl)c3)ncnc2cc1OCc1cc(Br)cc(Br)c1', 'text_b': None, 'label': 0},
#  {'guid': 980, 'text_a': 'O=C(Nc1ccccc1N1CCNCC1)c1csc(N2Cc3ccccc3C2)n1', 'text_b': None, 'label': 1},
#  {'guid': 988, 'text_a': 'CNC(=O)c1ccccc1Nc1cc(Nc2ccc(-n3nc(C)nc3C)cc2)ncc1C(F)(F)F', 'text_b': None, 'label': 0},
#  {'guid': 989, 'text_a': 'CCc1cccc(CC)c1NC(=O)c1nn(C)c2c1CCc1cnc(Nc3ccc(C(=O)NCCN(C)C)cc3OC)nc1-2', 'text_b': None, 'label': 0},
#  {'guid': 995, 'text_a': 'CC(C)CNc1cccn2c(-c3ccc(C(=O)NC4CC4)cc3)cnc12', 'text_b': None, 'label': 0},
#  {'guid': 996, 'text_a': 'C[C@H]1COCCN1c1nc(N2CCOC[C@@H]2C)c2ccc(-c3cccc(C(=O)NC4CCOCC4)c3)nc2n1', 'text_b': None, 'label': 0},
#  {'guid': 997, 'text_a': 'O=C1c2cc(-c3cn[nH]c3)ccc2-c2[nH]c3cc(-c4cn[nH]c4)ccc3c21', 'text_b': None, 'label': 0},
#  {'guid': 1001, 'text_a': 'O=C(CN1CCCC1)Nc1ccc2ncnc(Nc3ccc(Cl)cc3)c2c1', 'text_b': None, 'label': 1},
#  {'guid': 1011, 'text_a': 'C=CC(=O)N[C@H]1CN(c2nc(Nc3cnn(C)c3)c3ncn(C(C)C)c3n2)C[C@@H]1F', 'text_b': None, 'label': 0},
#  {'guid': 1012, 'text_a': 'O=C1Nc2cc(-c3ccc(O)cc3)ccc2/C1=C/c1cc[nH]c1', 'text_b': None, 'label': 1},
#  {'guid': 1018, 'text_a': 'Cn1c(=O)c(-c2c(Cl)cccc2Cl)cc2cnc(NCCCn3ccnc3)cc21', 'text_b': None, 'label': 0},
#  {'guid': 1021, 'text_a': 'O=c1[nH]c(N2CCOCC2)nc(N[C@@H]2CCNC2)c1-c1nc2ccccc2s1', 'text_b': None, 'label': 1},
#  {'guid': 1023, 'text_a': 'C[C@H]1COCCN1c1nc(N2CCOC[C@@H]2C)c2nc(-c3ccnc4[nH]ccc34)[nH]c2n1', 'text_b': None, 'label': 0},
#  {'guid': 1027, 'text_a': 'CCS(=O)(=O)Cc1ccc2c(c1)/C(=C/c1[nH]c3c(c1CCCN(C)C)CCCC3)C(=O)N2', 'text_b': None, 'label': 0},
#  {'guid': 1030, 'text_a': 'C=CC(=O)N1CC[C@H](Nc2nc(Nc3ccc(N4CCN(C)CC4)cc3)c3ncn(C(C)C)c3n2)C1', 'text_b': None, 'label': 0},
#  {'guid': 1033, 'text_a': 'COc1ccc(Nc2nc(-c3cccc(C(=O)Nc4ccc(-c5nn[nH]n5)cc4)c3)cn3ccnc23)cc1OC', 'text_b': None, 'label': 1},
#  {'guid': 1036, 'text_a': 'COCC(C)(NC(=O)Nc1cc2[nH]nc(OC)c2cn1)c1ccccc1', 'text_b': None, 'label': 0},
#  {'guid': 1038, 'text_a': 'C[C@@H]1CCCN(c2ncnc3[nH]cc(-c4cccc(C#N)c4)c23)C1', 'text_b': None, 'label': 0},
#  {'guid': 1049, 'text_a': 'COCC(CN(C)C)NC(=O)c1cc(NC(=O)c2cc(-c3ncccc3F)ccc2Cl)n(-c2ccccc2)n1', 'text_b': None, 'label': 0},
#  {'guid': 1052, 'text_a': 'Clc1cc2c3cc[nH]cc-3nc2c(Cl)c1OCC1CC1', 'text_b': None, 'label': 1},
#  {'guid': 1053, 'text_a': 'CC(C)c1cc(CNc2nc(Nc3cc(C(C)C)[nH]n3)cc(N3CCOCC3)n2)on1', 'text_b': None, 'label': 1},
#  {'guid': 1060, 'text_a': 'COc1cccc(Nc2ncc3cc(-c4c(Cl)cccc4Cl)c(=O)n(C)c3n2)c1', 'text_b': None, 'label': 1},
#  {'guid': 1064, 'text_a': 'CNS(=O)(=O)c1ccc(N(C)C)c(Nc2ncnc3cc[nH]c23)c1', 'text_b': None, 'label': 1},
#  {'guid': 1067, 'text_a': 'COc1ccc(COc2ccc(Cn3cnc4cc(C5=CC6(O)CCCN5C6)cnc43)cc2OC)cn1', 'text_b': None, 'label': 0},
#  {'guid': 1069, 'text_a': 'O=C1Cc2cnc(Nc3cccc(C(=O)NCCN4CCOCC4)c3)nc2-c2ccc(Cl)cc2N1', 'text_b': None, 'label': 0},
#  {'guid': 1071, 'text_a': 'CCCS(=O)(=O)Nc1ccc(OC)c(C(=O)Nc2cnc3[nH]nc(OC)c3c2)c1F', 'text_b': None, 'label': 0},
#  {'guid': 1078, 'text_a': 'COC(C)CN(C)c1ccncc1Nc1ncc2ccc(-c3c(F)cccc3F)nn12', 'text_b': None, 'label': 0},
#  {'guid': 1079, 'text_a': 'CC(CN)n1c(-c2nonc2N)nc2cnccc21', 'text_b': None, 'label': 1},
#  {'guid': 1081, 'text_a': 'OCc1ccc(-c2ccc(Oc3cncc4sc(-c5nn[nH]n5)cc34)cc2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1083, 'text_a': 'Cc1cccc(-c2c(-c3ccc4nccnc4c3)cnn2CC(=O)Nc2cccc(C#N)c2)n1', 'text_b': None, 'label': 0},
#  {'guid': 1087, 'text_a': 'CN1CCN(Cc2ccc(NC(=O)c3n[nH]cc3Nc3ncnc4ccsc34)cc2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 1090, 'text_a': 'Cn1c(=O)c(-c2c(Cl)cccc2Cl)cc2cnc(Nc3cccc(Br)c3)nc21', 'text_b': None, 'label': 0},
#  {'guid': 1099, 'text_a': 'FC(F)(F)c1ccc(CN2CCCC(c3nnn4cnc5[nH]ccc5c34)C2)cc1', 'text_b': None, 'label': 0},
#  {'guid': 1104, 'text_a': 'CC[C@@H](C)Oc1nc(Nc2ccc(S(N)(=O)=O)cc2)nc(N)c1C=O', 'text_b': None, 'label': 1},
#  {'guid': 1107, 'text_a': 'CCCCCC(=O)OCC1(CO)C/C(=C\\C=C(C(C)C)C(C)C)C(=O)O1', 'text_b': None, 'label': 1},
#  {'guid': 1109, 'text_a': 'C=CC(=O)Nc1cccc(NC(=O)Nc2ccnc(Nc3ccc(N4CCOCC4)cc3OC)n2)c1', 'text_b': None, 'label': 0},
#  {'guid': 1116, 'text_a': 'COc1ccc(-c2nc3c(NCCCNC(C)=O)c(Br)cnc3[nH]2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1121, 'text_a': 'CCOc1cccc(-c2nccc3c2cc(C(=O)O)n3CCOc2ccc(OC(F)(F)F)cc2)c1', 'text_b': None, 'label': 1},
#  {'guid': 1130, 'text_a': 'NC(=O)c1cnn2cc(-c3cncnc3)cc2c1NC1CCOCC1', 'text_b': None, 'label': 0},
#  {'guid': 1131, 'text_a': 'COc1ccc(-c2cnc3[nH]cc(-c4ccc(OC)c(OC)c4)c3c2)cc1OC', 'text_b': None, 'label': 1},
#  {'guid': 1133, 'text_a': 'CSC1CN(C(=O)c2n[nH]c3cc(NC(=O)N[C@H](C)c4ccccc4)ncc23)C1', 'text_b': None, 'label': 0},
#  {'guid': 1134, 'text_a': 'Cc1nn(C)c2c1-c1cnc(N)c(c1)OCc1cc(F)ccc1C(=O)N(C)C2', 'text_b': None, 'label': 1},
#  {'guid': 1145, 'text_a': 'Cn1cc(-c2ccc3cnc(Nc4ccc(-n5cnc(N6CCOCC6)n5)cc4)nc3c2C(F)(F)F)cn1', 'text_b': None, 'label': 0},
#  {'guid': 1150, 'text_a': 'N[C@H]1CCCC(F)(F)C1NC(=O)c1nc(-c2cnc3ccccn23)c(Cl)s1', 'text_b': None, 'label': 0},
#  {'guid': 1157, 'text_a': 'COCCN(c1ccnc(Nc2cc(N3CCOCC3)cc(N3CCOCC3)c2)n1)c1cc(CO)ccc1C', 'text_b': None, 'label': 0},
#  {'guid': 1159, 'text_a': 'C=CC(=O)Nc1cccc(Nc2nc(N/N=C/c3ccc(F)cc3)ncc2Cl)c1', 'text_b': None, 'label': 0},
#  {'guid': 1162, 'text_a': 'O=C(Nc1nccs1)C(c1cc(F)ccc1O)N1Cc2ccccc2C1=O', 'text_b': None, 'label': 1},
#  {'guid': 1163, 'text_a': 'CC(C)c1cc(Nc2cc(OC3CCN(C)CC3)nc(NCc3cc(-c4ccccc4)no3)n2)n[nH]1', 'text_b': None, 'label': 1},
#  {'guid': 1164, 'text_a': 'Nc1ncc(-c2cc(C3CCN(C4COC4)CC3)cc(N3CC(F)C3)n2)cn1', 'text_b': None, 'label': 0},
#  {'guid': 1167, 'text_a': 'CCOC(=O)c1cc2c(Nc3ccncc3)ncnn2c1', 'text_b': None, 'label': 1},
#  {'guid': 1171, 'text_a': 'COC(=O)c1c(CNC(=O)c2ccc3scnc3c2)c(=O)c2ccc(Cl)cc2n1-c1ccccc1', 'text_b': None, 'label': 1},
#  {'guid': 1174, 'text_a': 'COc1ccc(C(=O)NC(=O)Nc2ccc3c(c2)NC(=O)/C3=C\\c2[nH]c(C)c(CCC(=O)O)c2C)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1180, 'text_a': 'Nc1nccc(Oc2ccc(-n3cc(C(=O)NCc4ccc(F)cc4)ccc3=O)cc2F)c1C#CCO', 'text_b': None, 'label': 0},
#  {'guid': 1181, 'text_a': 'Cn1cnc(-c2cnc(O[C@@H]3CCN(C(=O)Cc4ccc(OC(F)(F)F)cc4)C[C@H]3F)c(C(N)=O)c2)c1', 'text_b': None, 'label': 0},
#  {'guid': 1182, 'text_a': 'O=C(NCC1CCCCC1)Nc1ccc(-c2cn[nH]c2)cc1', 'text_b': None, 'label': 0},
#  {'guid': 1184, 'text_a': 'Cc1cc(Nc2nc(Sc3ccc(Cl)cc3Cl)nc3ccccc23)n[nH]1', 'text_b': None, 'label': 1},
#  {'guid': 1190, 'text_a': 'CC(C)(C)Nc1c(Nc2ccnc(Nc3ccc4c(c3)Cc3ccccc3-4)n2)c(=O)c1=O', 'text_b': None, 'label': 1},
#  {'guid': 1193, 'text_a': 'CCN(CC)C(=O)OC[C@H](C)[C@H]1CC[C@@H](C)[C@@H](N(C)c2ncnc3[nH]ccc23)C1', 'text_b': None, 'label': 0},
#  {'guid': 1195, 'text_a': 'COCCNC(=O)c1ccc(-c2c(N)c(C(=O)c3ccc(F)cc3F)cc[n+]2[O-])c(C)c1', 'text_b': None, 'label': 1},
#  {'guid': 1196, 'text_a': 'Cn1cc(/C=C2\\C(=O)Nc3ccc(S(N)(=O)=O)cc32)c2ccccc21', 'text_b': None, 'label': 1},
#  {'guid': 1200, 'text_a': 'COCCNCc1ccc2ccc(Cl)c(C3=C(c4cn(C)c5ccccc45)C(=O)NC3=O)c2c1', 'text_b': None, 'label': 1},
#  {'guid': 1207, 'text_a': 'c1cc(-c2nc(N3CCNCC3)c3c4c(sc3n2)CCCC4)ccn1', 'text_b': None, 'label': 1},
#  {'guid': 1208, 'text_a': 'N#Cc1cncc(-c2n[nH]c3ccnc(OC4CCOCC4)c23)c1', 'text_b': None, 'label': 0},
#  {'guid': 1211, 'text_a': 'CC(C)c1cc(Nc2cc(OC3CCN(C)CC3)nc(NCc3cc(C(C)C)no3)n2)[nH]n1', 'text_b': None, 'label': 1},
#  {'guid': 1217, 'text_a': 'CCN(CC)CCOc1ccc(-c2cc(C(=O)Nc3cccc(CO)c3)c(NC(N)=O)s2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1218, 'text_a': 'CO/N=C/c1c(N)ncnc1Nc1ccc(F)c(Cl)c1', 'text_b': None, 'label': 1},
#  {'guid': 1220, 'text_a': 'c1cc2[nH]nc(-c3cnn(C4CCCC4)c3)c2c(NC2CCOCC2)n1', 'text_b': None, 'label': 0},
#  {'guid': 1221, 'text_a': 'Cc1n[nH]cc1-c1nc(NC2(C)CC2)c2ccncc2n1', 'text_b': None, 'label': 1},
#  {'guid': 1223, 'text_a': 'COC(=O)Nc1nc2cc(C3(O)c4ccccc4C(=O)N3c3cccc(OC(F)(F)C(F)F)c3)ccc2[nH]1', 'text_b': None, 'label': 0},
#  {'guid': 1224, 'text_a': 'COC(=O)c1ccc2c(c1)NC(=O)/C2=C(\\Nc1ccc(CN2CCCCC2)cc1)c1ccccc1', 'text_b': None, 'label': 1},
#  {'guid': 1226, 'text_a': 'O=C(N[C@@H](CO)c1ccc(F)c(Cl)c1)c1cc(-c2[nH]ncc2-c2cccc(Cl)c2)c[nH]1', 'text_b': None, 'label': 0},
#  {'guid': 1230, 'text_a': 'CN(C)[C@H]1CC[C@H](Nc2ncnc3cc(F)c(F)cc23)CC1', 'text_b': None, 'label': 0},
#  {'guid': 1233, 'text_a': 'O=S(=O)(NCCOCCCc1ccc(-c2cccnc2)cc1)c1cccc2cnccc12', 'text_b': None, 'label': 1},
#  {'guid': 1236, 'text_a': 'COC(=O)c1c(CNC(=O)c2ccc(-c3csc(C)n3)cc2)c(=O)c2ccc(Cl)cc2n1-c1ccccc1', 'text_b': None, 'label': 1},
#  {'guid': 1239, 'text_a': 'CN(Cc1ccccc1)C(=O)c1ccc(S(=O)(=O)Nc2ccc(F)cc2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1240, 'text_a': 'Cc1cccc(NC(=O)Nc2ccc(-c3ccc(OCCC(C)(C)N)c4[nH]nc(N)c34)c3ccccc23)c1', 'text_b': None, 'label': 1},
#  {'guid': 1242, 'text_a': 'COc1cc2c(cc1Nc1ncc(Cl)c(Nc3ccccc3S(=O)(=O)C(C)C)n1)CN(C(=O)CO)CCC2', 'text_b': None, 'label': 0},
#  {'guid': 1246, 'text_a': 'N#CCC(=O)N1CCC2(CCN(c3ncnc4[nH]ccc34)C2)C1', 'text_b': None, 'label': 0},
#  {'guid': 1247, 'text_a': 'CN1Cc2c(C3=CCNCC3(C)C)[nH]c3nccc(c23)-c2cc(F)ccc21', 'text_b': None, 'label': 0},
#  {'guid': 1253, 'text_a': 'c1ccc(COc2ccc3[nH]nc(-c4nc5cc(N6CCC(N7CCCCC7)CC6)ccc5[nH]4)c3c2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1254, 'text_a': 'Cc1ccc(-c2nc(NC3CC3)nc3sc(C(N)=O)c(N)c23)cc1O', 'text_b': None, 'label': 1},
#  {'guid': 1257, 'text_a': 'CCc1nn(-c2cccc(OC)c2)c2ncnc(N/N=C/c3ccncc3)c12', 'text_b': None, 'label': 1},
#  {'guid': 1261, 'text_a': 'CCCCCCCCCCCCCCCCNC(=O)COc1cc(O)c2c(=O)cc(-c3ccccc3)oc2c1', 'text_b': None, 'label': 1},
#  {'guid': 1262, 'text_a': 'CC(=O)Nc1ccc2[nH]nc(Cc3ccc(-c4cnn(C)c4)cc3)c2c1', 'text_b': None, 'label': 0},
#  {'guid': 1269, 'text_a': 'CN1CCN(CCCNc2ncc3cc(-c4c(Cl)cccc4Cl)c(NS(=O)(=O)c4ccccc4)nc3n2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 1273, 'text_a': 'CCCCNC(=O)Nc1ccc(-c2ccnc3[nH]nc(C)c23)cc1', 'text_b': None, 'label': 0},
#  {'guid': 1281, 'text_a': 'O=C(O)c1cccc(Nc2nccc(Nc3ccccc3Cl)n2)c1', 'text_b': None, 'label': 1},
#  {'guid': 1288, 'text_a': 'C=CC(=O)N1CC[C@@H](C)[C@@H](N(C)c2ncnc3[nH]ccc23)C1', 'text_b': None, 'label': 0},
#  {'guid': 1289, 'text_a': 'Oc1ccc2c(-c3ccnc(Nc4cccc(C(F)(F)F)c4)n3)cnn2n1', 'text_b': None, 'label': 1},
#  {'guid': 1293, 'text_a': 'CC(Oc1ccnc(Nc2cnn(C)c2)c1)c1cccc(C(=O)NCc2cc(C(F)(F)F)cc(C(F)(F)F)c2)c1', 'text_b': None, 'label': 0},
#  {'guid': 1297, 'text_a': 'CN1CCN(c2ncc(-c3cnc4[nH]ccc4n3)c(N[C@H]3CCCN(S(C)(=O)=O)C3)n2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 1299, 'text_a': 'CCNC(=O)Nc1ccc2ncc(-c3ccc(OC)c(OC)c3)nc2n1', 'text_b': None, 'label': 0},
#  {'guid': 1301, 'text_a': 'Nc1nccc2scc(-c3ccc(NC(=O)Nc4cccc(Cl)c4)cc3)c12', 'text_b': None, 'label': 1},
#  {'guid': 1304, 'text_a': 'N[C@H](CNc1ncc(-c2ccc3c(c2)CC(=O)N3)s1)Cc1ccc(C(F)(F)F)cc1', 'text_b': None, 'label': 0},
#  {'guid': 1306, 'text_a': 'COC(=O)c1c(Cc2ccc(C(=O)N[C@H](CO)C(C)(C)C)cc2)c(=O)c2cccnc2n1-c1ccccc1', 'text_b': None, 'label': 1},
#  {'guid': 1309, 'text_a': 'COc1ccc(NC(=O)Nc2ccc(-c3cccc4onc(N)c34)cc2)cc1Cl', 'text_b': None, 'label': 1},
#  {'guid': 1310, 'text_a': 'CC(C)(N)CNc1cc(-c2ccncc2)nc2cnccc12', 'text_b': None, 'label': 1},
#  {'guid': 1311, 'text_a': 'Oc1ccc2c3cnc(Nc4ccc(N5CCNCC5)cn4)nc3n(C3CCCC3)c2n1', 'text_b': None, 'label': 0},
#  {'guid': 1314, 'text_a': 'Cn1cc(-c2cnc3nnn(Cc4cc5cccnc5s4)c3n2)cn1', 'text_b': None, 'label': 0},
#  {'guid': 1317, 'text_a': 'CCCn1c2ccc(N)cc2c2c3c(c4c(c21)CCc1nn(C)cc1-4)C(=O)NC3', 'text_b': None, 'label': 1},
#  {'guid': 1318, 'text_a': 'O=C(Nc1ccc(O)cc1)c1ccc2c(-c3nc4ccc5ccccc5c4[nH]3)n[nH]c2c1', 'text_b': None, 'label': 0},
#  {'guid': 1319, 'text_a': 'CCOC(=O)C1CN(c2nc(N[C@@H]3CCCNC3)c(-c3nc4ccccc4s3)c(=O)[nH]2)CCO1', 'text_b': None, 'label': 0},
#  {'guid': 1322, 'text_a': 'CN(C)C1CCN(c2ccc(Nc3ncc4cc(C#N)n(C5CCCC5)c4n3)nc2)CC1', 'text_b': None, 'label': 0},
#  {'guid': 1324, 'text_a': 'O=C(Cc1cc(F)c(F)cc1F)Nc1cccc(Oc2cc(Nc3ccc(OCc4cccc(F)c4)c(Cl)c3)ncn2)c1', 'text_b': None, 'label': 0},
#  {'guid': 1327, 'text_a': 'CC(CO)/N=C(\\N)c1c(O)nsc1Nc1ccc(Oc2cccc(C(F)(F)F)c2F)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1329, 'text_a': 'Cc1cccc(-c2nn3c(c2-c2ccnc4ccc(C(N)=O)cc24)CCC3)n1', 'text_b': None, 'label': 0},
#  {'guid': 1333, 'text_a': 'CCOC(=O)c1cnc(Nc2ccccc2Cl)nc1Nc1cc(C2CC2)n[nH]1', 'text_b': None, 'label': 0},
#  {'guid': 1336, 'text_a': 'COc1ccc2c(c1)/C(=C/c1[nH]c3c(c1Cl)CN(C(C)=O)CC3)C(=O)N2', 'text_b': None, 'label': 1},
#  {'guid': 1337, 'text_a': 'C[C@@H](Oc1c[nH]c(=O)c(C(=O)Nc2ccc(CN3CCN(C)CC3)c(C(F)(F)F)c2)c1)c1c(Cl)ccc(F)c1Cl', 'text_b': None, 'label': 0},
#  {'guid': 1340, 'text_a': 'Nc1ncnc(N2CCN(C(CN3CCC3)c3ccc4c(c3)CCCC4)CC2)c1-c1cn[nH]c1', 'text_b': None, 'label': 0},
#  {'guid': 1342, 'text_a': 'COCCC(=O)Nc1cc(-c2ccnc(Nc3ccccc3)c2)ccn1', 'text_b': None, 'label': 1},
#  {'guid': 1345, 'text_a': 'O=C(Nc1cccc(-c2cnc3cc(Cl)ccn23)c1)NC1CC1', 'text_b': None, 'label': 0},
#  {'guid': 1350, 'text_a': 'CCC(C)(O)C#Cc1nc(Nc2ccc(OC)cc2)c2ncn(C(C)C)c2n1', 'text_b': None, 'label': 0},
#  {'guid': 1351, 'text_a': 'O=C(NCCCc1ccccc1)c1ccc2[nH]nc(-c3ccncc3)c2c1', 'text_b': None, 'label': 1},
#  {'guid': 1355, 'text_a': 'CN1CCC(C2CC=NN2C(=O)C(C)(C)C)CC1', 'text_b': None, 'label': 1},
#  {'guid': 1368, 'text_a': 'CNc1cc(-c2[nH]c(SCC(O)CO)nc2-c2ccc(F)cc2)ccn1', 'text_b': None, 'label': 0},
#  {'guid': 1369, 'text_a': 'COCCO[C@H]1CC[C@H](Nc2nccc(-n3ccc4c(N5CCN(C(C)=O)CC5)cccc43)n2)CC1', 'text_b': None, 'label': 0},
#  {'guid': 1372, 'text_a': 'O=C(c1ccc(O)cc1O)N(Cc1cccnc1)c1ccc(-c2nc3ccccc3nc2C(F)(F)F)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1377, 'text_a': 'COc1cc(/C=C2\\C(=O)Nc3ccc(Cl)cc32)ccc1OCCCC#N', 'text_b': None, 'label': 1},
#  {'guid': 1382, 'text_a': 'CC1(C)c2[nH]c3cc(C#N)ccc3c2C(=O)c2cccc(OC[C@@H](O)CO)c21', 'text_b': None, 'label': 0},
#  {'guid': 1384, 'text_a': 'Brc1c(Br)c(Br)c2[nH]c(N3CCN4CCC3CC4)nc2c1Br', 'text_b': None, 'label': 1},
#  {'guid': 1399, 'text_a': 'O=C1NC(=O)C(c2cccc([N+](=O)[O-])c2)=C1Nc1cccc(C(=O)O)c1', 'text_b': None, 'label': 1},
#  {'guid': 1405, 'text_a': 'OCc1ccc(C#Cc2cncnc2Nc2ccc(OCc3cccc(F)c3)c(Cl)c2)o1', 'text_b': None, 'label': 1},
#  {'guid': 1411, 'text_a': 'C[C@@H]1COCCN1c1nc(N2CCO[C@H](CO)C2)nc2[nH]c(-c3cccc4[nH]ccc34)nc12', 'text_b': None, 'label': 0},
#  {'guid': 1413, 'text_a': 'Cn1cc(-c2n[nH]c3c2CN(c2ccn(Cc4ccccc4)c(=O)c2)CC3)ccc1=O', 'text_b': None, 'label': 1},
#  {'guid': 1416, 'text_a': 'Oc1ccc(Cc2nnc3ccc(-c4cccs4)nn23)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1418, 'text_a': 'NS(=O)(=O)c1ccc(Nc2nccc(-c3ccccc3[N+](=O)[O-])n2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 1425, 'text_a': 'COc1cc2ncnc(Oc3cccc(NC(=O)Nc4cc(C5(C(F)(F)F)CCC5)no4)c3)c2cc1OC', 'text_b': None, 'label': 0},
#  {'guid': 1444, 'text_a': 'Cc1cn2c(-c3cnn(CC(=O)NCCN(C)C)c3)cnc2c(Nc2cc(CN3CCCC(C)C3)ns2)n1', 'text_b': None, 'label': 0},
#  {'guid': 1454, 'text_a': 'CC(C)N1CCc2nc(NC(=O)N[C@H](C)c3ccccc3)cc3[nH]nc1c23', 'text_b': None, 'label': 1},
#  {'guid': 1457, 'text_a': 'CN1CCN(c2nc(NCc3nc4c(F)c(F)ccc4[nH]3)c3ncn(-c4ccsc4)c3n2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 1462, 'text_a': 'CN(C)C(=O)c1ccc(-c2cnc(N)c(C(=O)Nc3ccccc3)n2)cc1Cl', 'text_b': None, 'label': 1},
#  {'guid': 1464, 'text_a': 'COc1cc(OC)cc(N(CCCN2CCC(C3C[C@@H](C)O[C@H](C)C3)C2)c2ccc3ncc(-c4cnn(C)c4)nc3c2)c1.Cl', 'text_b': None, 'label': 0},
#  {'guid': 1465, 'text_a': 'N#Cc1cnc2ccc(NCc3cccc(N)c3)cc2c1Nc1ccc(F)c(Cl)c1', 'text_b': None, 'label': 0},
# ...
#  {'guid': 2744, 'text_a': 'O=C(Nc1cc2cc[nH]c(=O)c2cc1Cl)C1(c2ccccc2)CCNCC1', 'text_b': None, 'label': 0},
#  {'guid': 2745, 'text_a': 'COc1cc2nccc(Oc3ccc(NC(=S)NC(=O)Cc4ccccc4)cn3)c2cc1OC', 'text_b': None, 'label': 1},
#  {'guid': 2747, 'text_a': 'CCC(C)(C)C(=O)N(C)Cc1cc(F)ccc1F', 'text_b': None, 'label': 1},
#  {'guid': 2750, 'text_a': 'CN(C)Cc1ccncc1NC(=O)c1nc(-c2ccc(S(=O)(=O)N3CCCC3)cc2)cnc1N', 'text_b': None, 'label': 1},
#  {'guid': 2751, 'text_a': 'NS(=O)(=O)c1ccc(-c2cc3ccncc3cc2OCC2CCCNC2)cc1', 'text_b': None, 'label': 0},
#  {'guid': 2759, 'text_a': 'CN(C)CCCc1[nH]cnc1CNc1cc(Cl)c2ncc(C#N)c(Nc3ccc(F)c(Cl)c3)c2c1', 'text_b': None, 'label': 0},
#  {'guid': 2763, 'text_a': 'Nc1ncnc(N2CCN(Cc3ccc(C(F)(F)F)cc3)CC2)c1-c1ccc(F)cc1', 'text_b': None, 'label': 1},
#  {'guid': 2767, 'text_a': 'CNC(=O)c1ccccc1Nc1nc(Nc2ccc(CN)cc2)n2ccnc2n1', 'text_b': None, 'label': 0},
#  {'guid': 2771, 'text_a': 'CC(C)Nc1nc(Nc2ccc(S(C)(=N)=O)cc2)ncc1Br', 'text_b': None, 'label': 1},
#  {'guid': 2772, 'text_a': 'O=C(NCCCO)c1cncc(-c2cncc(Nc3cccc(Cl)c3)n2)c1', 'text_b': None, 'label': 0},
#  {'guid': 2773, 'text_a': 'Cc1ccc(NC(=O)c2ccccc2Cn2ccc3cnccc32)c(F)c1', 'text_b': None, 'label': 0},
#  {'guid': 2780, 'text_a': 'CCOC(=O)c1c[nH]c2ncnc(-c3ccc(N(C)C)cc3)c12', 'text_b': None, 'label': 1},
#  {'guid': 2789, 'text_a': 'O=c1ccc2nccc3c4ccc(O[C@@H]5O[C@H](CO)[C@@H](O)[C@H](O)[C@H]5O)cc4n1c23', 'text_b': None, 'label': 0},
#  {'guid': 2791, 'text_a': 'CNCc1ccc(C2=NOC(c3nc(-c4ccc(S(=O)(=O)C(C)C)cc4)cnc3N)C2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 2796, 'text_a': 'COc1ccc(-c2c(-c3ccnc(NC(C)=O)c3)[nH]c3cccnc23)nc1', 'text_b': None, 'label': 1},
#  {'guid': 2797, 'text_a': 'Cc1cccc(C)c1-c1cc(C)c2nc(Nc3ccc(C(=O)O)o3)nnc2c1', 'text_b': None, 'label': 0},
#  {'guid': 2798, 'text_a': 'CC(C)Oc1cc(F)cc(-c2c[nH]c3ccc(-c4nnc(N)o4)cc23)c1', 'text_b': None, 'label': 0},
#  {'guid': 2802, 'text_a': 'CN1Cc2c(C3=CCCN(C4CCC(=CC(=O)O)CC4)CC3)[nH]c3nccc(c23)-c2cc(F)ccc21', 'text_b': None, 'label': 0},
#  {'guid': 2803, 'text_a': 'NCCCC[C@H](NC(=O)[C@H](CC(=O)O)NC(=O)[C@H](CC(=O)O)NC(=O)[C@H](CC(=O)O)NC(=O)[C@H](CC(=O)O)NC(=O)[C@H](CC(=O)O)NC(=O)[C@H](CC(=O)O)NC(=O)CCCCCCCn1cnc2c(Br)c(Br)c(Br)c(Br)c21)C(=O)O', 'text_b': None, 'label': 1},
#  {'guid': 2804, 'text_a': 'COc1ccc(NC(=O)CCCN(C)C)cc1Nc1ncc(Cl)c(-c2cnn3ccccc23)n1', 'text_b': None, 'label': 0},
#  {'guid': 2807, 'text_a': 'O=C(Nc1ccc(Cl)cc1)c1cccnc1SCc1ccncc1', 'text_b': None, 'label': 1},
#  {'guid': 2808, 'text_a': 'CNc1ncc2c(-c3ccc(N4CCN(C(=O)C(C)(C)C)CC4)nc3)nn(Cc3cn(Cc4ccccc4)nn3)c2n1', 'text_b': None, 'label': 0},
#  {'guid': 2813, 'text_a': 'c1cc2c(ncc3ncn(C4CCNCC4)c32)[nH]1', 'text_b': None, 'label': 1},
#  {'guid': 2816, 'text_a': 'COc1ccc2c(c1OC)N=C(NC(=O)c1cccnc1)N1CCN=C21', 'text_b': None, 'label': 1},
#  {'guid': 2819, 'text_a': 'CC1(C)CCN(c2nc3c(c(Nc4cc(C5CC5)[nH]n4)n2)CCC3)CC1', 'text_b': None, 'label': 0},
#  {'guid': 2820, 'text_a': 'CC(C)Nc1c(C(N)=O)nnc2ccc(-c3cnn(C)c3)cc12', 'text_b': None, 'label': 0},
#  {'guid': 2823, 'text_a': 'O=C1NC(=O)/C(=C\\c2ccc(-c3cccc(Br)c3)o2)S1', 'text_b': None, 'label': 1},
#  {'guid': 2824, 'text_a': 'c1cnc2ccc(Cn3cnc4ncc(-c5cn[nH]c5)nc43)cc2c1', 'text_b': None, 'label': 1},
#  {'guid': 2827, 'text_a': 'Oc1ccc(-c2ccc3c(-c4cnn(C5CCNCC5)c4)n[nH]c3n2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 2831, 'text_a': 'C=CC(=O)N1CCC[C@@H](n2nc(-c3cncnc3)c3c(N)ncnc32)C1', 'text_b': None, 'label': 0},
#  {'guid': 2835, 'text_a': 'CCNc1ccc(S(=O)(=O)NC)cc1Nc1cc(Nc2ccc(Cl)cc2)ncn1', 'text_b': None, 'label': 0},
#  {'guid': 2843, 'text_a': 'Cc1cc(Nc2ccnc(Nc3ccc(N4CCOCC4)cc3)n2)no1', 'text_b': None, 'label': 1},
#  {'guid': 2845, 'text_a': 'COc1cc2sc(-c3c(N)n[nH]c3C3CC3c3ccccc3)nc2cc1F', 'text_b': None, 'label': 0},
#  {'guid': 2846, 'text_a': 'CC(=O)N[C@@H](Cc1ccc(OP(=O)(O)O)cc1)C(=O)N[C@H]1CCCCc2cc(OCC3CCCCC3)c(C(N)=O)cc21', 'text_b': None, 'label': 1},
#  {'guid': 2847, 'text_a': 'Cc1cc(Nc2nc(C(=O)N3CCNC(=O)C3)nc3ccc(Cl)cc23)n[nH]1', 'text_b': None, 'label': 0},
#  {'guid': 2848, 'text_a': 'CC(=O)C1=C(O)C=C2Oc3c(C(N)=O)c(O)cc(O)c3[C@@]2(C)C1=O', 'text_b': None, 'label': 1},
#  {'guid': 2849, 'text_a': 'Cc1cnc(Nc2ccc(OCC(=O)O)cc2)nc1-c1cc2ccccc2o1', 'text_b': None, 'label': 1},
#  {'guid': 2850, 'text_a': 'Brc1c(Br)c(Br)c2[nH]c(Nc3ccccc3)nc2c1Br', 'text_b': None, 'label': 1},
#  {'guid': 2852, 'text_a': 'CN(C)S(=O)(=O)c1ccc(-c2c(O)ccc3[nH]c(=O)c4sccc4c23)cc1', 'text_b': None, 'label': 1},
#  {'guid': 2857, 'text_a': 'CC(C)CC(C/C=C1\\CC(CO)(CN(O)C(=O)C(C)(C)C)OC1=O)CC(C)C', 'text_b': None, 'label': 1},
#  {'guid': 2861, 'text_a': 'CNc1cccc(-c2cnc3[nH]cc(-c4ccncc4)c3c2)c1', 'text_b': None, 'label': 1},
#  {'guid': 2864, 'text_a': 'CC(=O)Nc1nc2ccc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(C(C)(C)C)cc4)c3)cc2s1', 'text_b': None, 'label': 1},
#  {'guid': 2867, 'text_a': 'O=C1NCN(C2CCCCC2)c2c1cnc1[nH]ccc21', 'text_b': None, 'label': 1},
#  {'guid': 2871, 'text_a': 'COC(=O)Nc1nc2ccc(C3(O)c4c(Cl)ccc(Cl)c4C(=O)N3c3cccc(Cl)c3F)cc2[nH]1', 'text_b': None, 'label': 0},
#  {'guid': 2872, 'text_a': 'NC(=O)c1cc2nc(-c3ccc(Oc4ccc(Cl)c(Cl)c4)cc3)[nH]c2cc1Cl', 'text_b': None, 'label': 0},
#  {'guid': 2877, 'text_a': 'Cc1cc(-c2c(C3=CCCCCC3)c3cc(Cl)ccc3[nH]c2=O)on1', 'text_b': None, 'label': 1},
#  {'guid': 2878, 'text_a': 'CCN(CC)CC(O)CNC(=O)c1c(C)[nH]c2c1CCC/C2=C1/C(=O)Nc2ccc(F)cc21', 'text_b': None, 'label': 1},
#  {'guid': 2880, 'text_a': 'NC(=O)c1cc(-c2ccc(Cl)c(Cl)c2)cc2c3c([nH]c12)CCC(C(=O)N1CCOCC1)C3', 'text_b': None, 'label': 0},
#  {'guid': 2881, 'text_a': 'CC(=O)OCOC(=O)N1CCN(c2ccc(Nc3ncc4c(C)c(C(C)=O)c(=O)n(C5CCCC5)c4n3)nc2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 2882, 'text_a': 'COc1cc2c(Nc3ccc(Cl)c(Cl)c3)ncnc2cc1OCc1cc(F)cc(F)c1', 'text_b': None, 'label': 0},
#  {'guid': 2884, 'text_a': 'CCN1CCN(Cc2ccc(NC(=O)CNc3ccc(-c4cccnc4)cc3)cc2C(F)(F)F)CC1', 'text_b': None, 'label': 1},
#  {'guid': 2891, 'text_a': 'Cc1nn(C)cc1-c1nc2c(Oc3ccc(C(=O)NCc4ccccc4)cc3)c(Cl)cnc2[nH]1', 'text_b': None, 'label': 0},
#  {'guid': 2893, 'text_a': 'CC[C@@H]1C(=O)N(C)c2cnc(-n3ccc4cc(F)ccc43)nc2N1C1CCCC1', 'text_b': None, 'label': 0},
#  {'guid': 2895, 'text_a': 'CCc1cccc(CC)c1NC(=O)c1nn(C)c2c1CCc1cnc(Nc3ccc(C(=O)N4CCC[C@@H]4CN4CCCC4)cc3OC(F)(F)F)nc1-2', 'text_b': None, 'label': 0},
#  {'guid': 2896, 'text_a': 'CNCc1cc(Oc2ccc3c(ccn3C(=O)Nc3cc(C4CC4)on3)c2)ncn1', 'text_b': None, 'label': 0},
#  {'guid': 2897, 'text_a': 'c1cncc(-c2cc3c(N4CCCC4)n[nH]c3cn2)c1', 'text_b': None, 'label': 1},
#  {'guid': 2903, 'text_a': 'COc1cc(Nc2nccc(Nc3cc4ccccc4cn3)n2)cc(OC)c1OC', 'text_b': None, 'label': 1},
#  {'guid': 2904, 'text_a': 'CC(C)(C)c1cc(NC(=O)Nc2ccc(NC(=O)c3cc4ccccc4cn3)cc2)no1', 'text_b': None, 'label': 1},
#  {'guid': 2907, 'text_a': 'COc1cc(-c2ccnc3[nH]cc(C#N)c23)ccc1CN1CCOCC1', 'text_b': None, 'label': 0},
#  {'guid': 2910, 'text_a': 'CN(c1cc(Nc2ccccn2)ncn1)C1CCCCC1', 'text_b': None, 'label': 0},
#  {'guid': 2914, 'text_a': 'CS(=O)(=O)c1cccc(-c2[nH]nc3ccnc(OC4CCOCC4)c23)c1', 'text_b': None, 'label': 1},
#  {'guid': 2918, 'text_a': 'O=C1/C(=C/c2c[nH]c3ncccc23)Oc2cc(O)ccc21', 'text_b': None, 'label': 1},
#  {'guid': 2922, 'text_a': 'O=C(/C=C/N1CCOCC1)Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1', 'text_b': None, 'label': 0},
#  {'guid': 2923, 'text_a': 'Cc1[nH]nc2c1N=C(c1ccccc1Cl)c1cc([N+](=O)[O-])ccc1N2', 'text_b': None, 'label': 1},
#  {'guid': 2925, 'text_a': 'COC(=O)Nc1ccc(-c2c(OC3CCN(C)CC3)nc3c(-c4ccc(OC)c(OC)c4)cnn3c2N)cc1', 'text_b': None, 'label': 0},
#  {'guid': 2928, 'text_a': 'C=CCCn1cc(-c2ccc(NC(=O)Nc3cc(C(C)(C)C)on3)cc2)c2c(N)ncnc21', 'text_b': None, 'label': 1},
#  {'guid': 2932, 'text_a': 'CN(C)CCC(C)(C)Nc1nc(-c2ccncc2)nc2cnccc12', 'text_b': None, 'label': 1},
#  {'guid': 2935, 'text_a': 'CC1(C)c2cc(OC3COC[C@@H]3O)ccc2C(=O)c2c1[nH]c1cc(Br)ccc21', 'text_b': None, 'label': 0},
#  {'guid': 2937, 'text_a': 'COc1ccc(C(N)=O)c2ncnc(NCc3ccccc3)c12', 'text_b': None, 'label': 1},
#  {'guid': 2939, 'text_a': 'CCS(=O)(=O)c1ccc(OC)c(Nc2ncc(-c3ccc(C#N)cc3)o2)c1', 'text_b': None, 'label': 1},
#  {'guid': 2942, 'text_a': 'COC[C@H](Cc1ccc(O)cc1)NC(=O)c1cc(C(=O)O)c2cc(-c3cccc(C(F)(F)F)c3)ccc2n1', 'text_b': None, 'label': 1},
#  {'guid': 2946, 'text_a': 'NCCNC(c1ccc(Cl)cc1)c1ccc(-c2cn[nH]c2)cc1', 'text_b': None, 'label': 0},
#  {'guid': 2948, 'text_a': 'N#Cc1ccc(-c2c(-c3ncn[nH]3)sc(N3CCOCC3)c2C#N)c(F)c1', 'text_b': None, 'label': 0},
#  {'guid': 2950, 'text_a': 'CC1CCN(c2nc(Nc3cc(C4CC4)[nH]n3)c3ccccc3n2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 2963, 'text_a': 'Cc1ccc(NC(=O)c2cc(C#N)cc(C(F)(F)F)c2)cc1-n1ccn2nc(-c3cccnc3)cc12', 'text_b': None, 'label': 0},
#  {'guid': 2967, 'text_a': 'CC#CCC1CNC(=O)c2cc(-c3cccc4nc(C)c(F)nc34)[nH]c21', 'text_b': None, 'label': 0},
#  {'guid': 2969, 'text_a': 'COc1cc(CNc2nc(-c3cccc(C)n3)c(-c3ccc4ncnn4c3)s2)cc(OC)c1', 'text_b': None, 'label': 1},
#  {'guid': 2970, 'text_a': 'COc1cc2c(Nc3ccc(Sc4nccn4C)c(Cl)c3)c(C#N)cnc2cc1OCCCN(C)CCO', 'text_b': None, 'label': 0},
#  {'guid': 2971, 'text_a': 'Cc1ccc(C(=O)NC2CCCCC2)cc1C(=O)Nc1ccc(N)nc1', 'text_b': None, 'label': 0},
#  {'guid': 2975, 'text_a': 'NC(=O)c1c(Nc2ccc(I)cc2F)cc(F)cc1Oc1cccc(F)c1NS(N)(=O)=O', 'text_b': None, 'label': 0},
#  {'guid': 2976, 'text_a': 'CC(=O)Nc1cccc(CNc2nnc(-c3ccc4[nH]cc(-c5ccccc5F)c4c3)s2)c1', 'text_b': None, 'label': 0},
#  {'guid': 2977, 'text_a': 'C[C@@H]1CO[C@H](C(=O)Nc2ccccc2)CN1c1cc(-c2ccc3c(N)n[nH]c3c2)nc(N)n1', 'text_b': None, 'label': 0},
#  {'guid': 2980, 'text_a': 'CNC(=O)c1ccc(Sc2ccc(NC(=O)Nc3cc(C(F)(F)F)cc(C(F)(F)F)c3)cc2)nc1', 'text_b': None, 'label': 1},
#  {'guid': 2982, 'text_a': 'COC(=O)N[C@H](C(=O)Nc1n[nH]c2cc(NC(=O)N[C@H](C)c3ccc(F)cc3)ncc12)C1CCOCC1', 'text_b': None, 'label': 0},
#  {'guid': 2986, 'text_a': 'NC(=O)c1cnc(N[C@@H]2CCCC[C@@H]2N)nc1Nc1cccc(-n2nccn2)c1', 'text_b': None, 'label': 0},
#  {'guid': 2987, 'text_a': 'c1ccc(-c2c(-c3ccc(OCCN4CCCC4)cc3)oc3ncnc(NC[C@@H]4CCCO4)c23)cc1', 'text_b': None, 'label': 1},
#  {'guid': 2991, 'text_a': 'NCCCNc1cc(-c2ccc[nH]2)c2c3c(ccc(F)c13)NC2=O', 'text_b': None, 'label': 1},
#  {'guid': 2999, 'text_a': 'O=C(Nc1ccc(CCc2nc3ccccc3[nH]2)cc1)Nc1cccc(C(F)(F)F)c1', 'text_b': None, 'label': 1},
#  {'guid': 3006, 'text_a': 'COCC(=O)Nc1ccc2ncnc(Nc3cc(Cl)c(Cl)cc3F)c2c1', 'text_b': None, 'label': 0},
#  {'guid': 3009, 'text_a': 'CCN(CC)C1CCN(C(=O)c2ccc(Nc3ncc4cc5n(c4n3)C3(CCCCC3)CNC5=O)nc2)C1', 'text_b': None, 'label': 0},
#  {'guid': 3015, 'text_a': 'Fc1ccc(-c2nn3c(OCC(F)(F)F)cccc3c2-c2ccncc2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 3017, 'text_a': 'C#CC(=O)N1CCC[C@@H](n2nc(C#CCOc3ccccc3)c3c(N)ncnc32)C1', 'text_b': None, 'label': 1},
#  {'guid': 3021, 'text_a': 'CCNC(=O)c1ccc(C)c(Nc2nc(N[C@H]3CCNC3)nc(N(C)CC(C)(C)C)n2)c1', 'text_b': None, 'label': 1},
#  {'guid': 3022, 'text_a': '[C-]#[N+]/C(=C/c1ccc(Nc2cnc3[nH]cc(C(=O)C(C)(C)C)c3n2)cc1)c1nccs1', 'text_b': None, 'label': 0},
#  {'guid': 3025, 'text_a': 'C[C@@H]1C[C@H]1C(=O)N1CCN(c2cnc(C#N)c(-c3cnn(C)c3)n2)C[C@H]1C', 'text_b': None, 'label': 0},
#  {'guid': 3026, 'text_a': 'O=C(c1cc2ccccc2s1)c1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2s1', 'text_b': None, 'label': 1},
#  {'guid': 3028, 'text_a': 'O=S(=O)(Cc1ccccc1)Nc1ccc(F)c(Nc2ncccc2-c2ncnc3[nH]cnc23)c1F', 'text_b': None, 'label': 0},
#  {'guid': 3030, 'text_a': 'CN(C)[C@H]1CC[C@H](Nc2ncnc3ccc(Br)cc23)CC1', 'text_b': None, 'label': 1},
#  {'guid': 3039, 'text_a': 'CN(C)c1cc2ncnc(Nc3cccc(Br)c3)c2cc1[N+](=O)[O-]', 'text_b': None, 'label': 0},
#  {'guid': 3042, 'text_a': 'Cn1cc(-c2cnc3[nH]cc(-c4cnn(Cc5cccc(C(F)(F)F)c5)c4)c3c2)cn1', 'text_b': None, 'label': 0},
#  {'guid': 3043, 'text_a': 'COc1ccc(Nc2nc(C)nc3c(Cc4ccccc4)cn(C)c23)cc1.Cl', 'text_b': None, 'label': 1},
#  {'guid': 3044, 'text_a': 'CC[C@@]1(C(=O)Nc2ccc3[nH]nc(-c4ccc(F)cc4)c3c2)CCN(CC(=O)N2CC=C(c3ccc(-c4ncccn4)cc3)CC2)C1', 'text_b': None, 'label': 0},
#  {'guid': 3049, 'text_a': 'c1cc2c(ncn3nnc(C4CCN(Cc5cncs5)CC4)c23)[nH]1', 'text_b': None, 'label': 1},
#  {'guid': 3053, 'text_a': 'COc1cc(C(=O)NC2CCN(C)CC2)ccc1Nc1ncc2c(n1)N(C)c1ccccc1C(=O)N2C(C)C', 'text_b': None, 'label': 0},
#  {'guid': 3055, 'text_a': 'CC(C)(Nc1cccc(C(=O)NCCC(N)=O)c1)C(=O)Nc1nc2c(C(F)(F)F)cc3[nH]ncc3c2s1', 'text_b': None, 'label': 0},
#  {'guid': 3060, 'text_a': 'CC(=O)Nc1cccc(-c2ccc(C(N)=O)c3[nH]c4cc(C(=O)N5CCN(C)CC5)ccc4c23)c1C', 'text_b': None, 'label': 0},
#  {'guid': 3063, 'text_a': 'CC(C)(CN)CNc1nc2cc[nH]c(=O)c2c2cc(F)ccc12', 'text_b': None, 'label': 0},
#  {'guid': 3065, 'text_a': 'CCN1CCN(Cc2ccc(NC(=O)COc3ccc(-c4ccc(C(=O)NC)nc4)cc3)cc2C(F)(F)F)CC1', 'text_b': None, 'label': 0},
#  {'guid': 3074, 'text_a': 'CC(C)(C)c1cc(NC(=O)Nc2ccc(-c3cc(N)n[nH]3)cc2)no1', 'text_b': None, 'label': 0},
#  {'guid': 3075, 'text_a': 'Cc1ccc(-c2c(C(=O)CCl)n(CCCO)c3ncnc(N)c23)cc1', 'text_b': None, 'label': 1},
#  {'guid': 3084, 'text_a': 'Cc1cc(Nc2nc(Nc3ccccc3)nc3ccccc23)n[nH]1', 'text_b': None, 'label': 1},
#  {'guid': 3088, 'text_a': 'O=S(=O)(c1ccccc1Cl)c1c[nH]c2ncc(-c3cnn(C4CCNCC4)c3)cc12', 'text_b': None, 'label': 0},
#  {'guid': 3092, 'text_a': 'Nc1ncc(-c2cnn(C3CCNCC3)c2)cc1-c1nc2ccc(Nc3ccccn3)cc2o1', 'text_b': None, 'label': 0},
#  {'guid': 3093, 'text_a': 'S=C(NCc1ccccc1)Nc1ccc2ncnc(Nc3cccc(Cl)c3)c2c1', 'text_b': None, 'label': 1},
#  {'guid': 3097, 'text_a': 'CCCS(=O)(=O)Nc1ccc(F)c(Nc2ccc3ncn(Cc4ccccc4)c(=O)c3c2)c1Cl', 'text_b': None, 'label': 1},
#  {'guid': 3100, 'text_a': 'NC(=O)c1sc(-c2cnc3ccccn23)cc1OCc1ccccc1Cl', 'text_b': None, 'label': 1},
#  {'guid': 3104, 'text_a': 'COc1cc(-c2ccnc(Nc3ccc(N4CCOCC4)cc3)n2)ccc1N', 'text_b': None, 'label': 1},
#  {'guid': 3107, 'text_a': 'CC(C)CNc1cccc2c1ncn2-c1ccc(C(=O)NC2CC2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 3109, 'text_a': 'CN(C)C(=O)c1cc2cnc(Nc3ccc(C(=O)C45C[C@H]6C[C@H](O)C[C@@H](C4)N65)cn3)nc2n1C1CCCC1', 'text_b': None, 'label': 0},
#  {'guid': 3110, 'text_a': 'COCCNc1nc(-c2ccc3c(c2)S(=O)(=O)CCN3C)cc2ncn(C)c(=O)c12', 'text_b': None, 'label': 1},
#  {'guid': 3121, 'text_a': 'CN(CC1CCN(C(=O)OC(C)(C)C)CC1)C(=O)c1ccc(S(=O)(=O)Nc2ccccc2)cc1', 'text_b': None, 'label': 1},
#  {'guid': 3126, 'text_a': 'O[C@H]1CC[C@H](Oc2ccc3ncc(-c4cccc(OC(F)(F)F)c4)n3n2)CC1', 'text_b': None, 'label': 1},
#  {'guid': 3131, 'text_a': 'Cc1cccc2ncnc(N3CCN(C(=O)[C@H](N)Cc4ccc(Cl)cc4)CC3)c12', 'text_b': None, 'label': 1},
#  {'guid': 3135, 'text_a': 'Cn1cc(C(=O)c2cncc(NC(=O)Nc3ccc(C(F)(F)F)cc3)c2)c2cncnc21', 'text_b': None, 'label': 1},
#  {'guid': 3136, 'text_a': 'COc1cc2c(Nc3ccc(Sc4nc5cc(C)ccc5n4C)c(Cl)c3)c(C#N)cnc2cc1NCCCN(C)C', 'text_b': None, 'label': 0},
#  {'guid': 3139, 'text_a': 'CC(C)n1cnc2cnc(Nc3ccnc(N4CCC(C(N)=O)CC4)n3)cc21', 'text_b': None, 'label': 0},
#  {'guid': 3141, 'text_a': 'NC(=O)C1(c2ccccc2CCc2nc(Nc3ncco3)ncc2Cl)CC1', 'text_b': None, 'label': 0},
#  {'guid': 3144, 'text_a': 'COc1ccccc1-c1ccc(CNc2nc(NC3CCC(N)CC3)nc3c2ncn3C2CCCC2)cc1', 'text_b': None, 'label': 0},
#  {'guid': 3145, 'text_a': 'CC1CCc2c(sc3nc(-c4ccncc4)nc(NC[C@H](C)N)c23)C1', 'text_b': None, 'label': 0},
#  {'guid': 3151, 'text_a': 'COc1cccc(CN(CCN(C)C)C(=O)Nc2ccc(-c3cn[nH]c3)cn2)c1', 'text_b': None, 'label': 1},
#  {'guid': 3157, 'text_a': 'CC(C)(O)C#Cc1ccc2ncnc(Nc3ccc(F)c(Cl)c3)c2c1', 'text_b': None, 'label': 0},
#  {'guid': 3160, 'text_a': 'COCCOc1ccn2c(-c3ccc4cccc(OCc5cnc[nH]5)c4n3)cnc2c1', 'text_b': None, 'label': 0},
#  {'guid': 3169, 'text_a': 'Clc1ccnc2[nH]c(-c3ccc(N4CCNCC4)cc3)cc12', 'text_b': None, 'label': 1},
#  {'guid': 3172, 'text_a': 'NC(O)C1CCC(c2cccc(Nc3nccc(Nc4cccc(C(F)(F)F)c4)n3)c2)C1', 'text_b': None, 'label': 0},
#  {'guid': 3175, 'text_a': 'Nc1ccc(C2Nc3ccccc3-c3ccnc4[nH]cc2c34)cc1', 'text_b': None, 'label': 1},
#  {'guid': 3182, 'text_a': 'Nc1cn2cc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(F)cc4)c3)ccc2n1', 'text_b': None, 'label': 1},
#  {'guid': 3186, 'text_a': 'Cc1ccc(-c2nn(C3Cc4ccccc4C3)c3ncnc(N)c23)cc1O', 'text_b': None, 'label': 1},
#  {'guid': 3187, 'text_a': 'CN(C)CCCn1c2ccc(O)cc2c2c3c(c(-c4ccccc4Cl)cc21)C(=O)NC3=O', 'text_b': None, 'label': 1},
#  {'guid': 3191, 'text_a': 'COc1cc2ncnc(Sc3nncs3)c2cc1OC', 'text_b': None, 'label': 1},
#  {'guid': 3196, 'text_a': 'CS(=O)(=O)Cc1cc(N2CCOCC2)nc(-c2cccc3[nH]ccc23)n1', 'text_b': None, 'label': 0},
#  {'guid': 3198, 'text_a': 'NC(=O)c1cc(-c2ccncc2)[nH]c1-c1ccccc1[N+](=O)[O-]', 'text_b': None, 'label': 1},
#  {'guid': 3200, 'text_a': 'CCCC(=O)Nc1n[nH]c2cc(-c3ccc(C(C)(C)C)cc3)ccc12', 'text_b': None, 'label': 0},
#  {'guid': 3215, 'text_a': 'Cc1cccc(Oc2cnc(O)nc2)c1', 'text_b': None, 'label': 1},
#  ...]

# %% [markdown]
# The model performs pretty well, averaging above 97% ROC-PRC after training on only ~1400 data samples and 150 positive leads in a couple of minutes! We can clearly see the predictive power of transfer learning, and approaches like these are becoming increasing popular in the pharmaceutical industry where larger datasets are scarce. By training on more epochs and tasks, we can probably boost the accuracy as well!
#
# Lets evaluate the model on one last string from ClinTox's test set for toxicity. The model should predict 1, meaning the drug failed clinical trials for toxicity reasons and wasn't approved by the FDA.

# %%
# Lets input a molecule with a toxicity value of 1
mol = "C1=C(C(=O)NC(=O)N1)F"
# mol = "Nc1nc(NC2CC2)c2ncn([C@H]3C=C[C@@H](CO)C3)c2n1"

predictions, raw_outputs = model.predict([mol])
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(predictions)
print(raw_outputs)
# Out:
# [0]
# [[ 1.46777344 -1.59082031]]
